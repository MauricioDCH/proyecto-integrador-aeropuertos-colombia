# %% [markdown]
# # EDA — Clasificación del nivel de operación aérea mensual por aeropuerto en Colombia
#
# En este notebook se realiza el Análisis Exploratorio de Datos (EDA) sobre el dataset Gold construido en el pipeline de ingesta. El análisis sigue la metodología CRISP-DM y cubre:
#
# 0. Imports y configuración
# 1. Carga del dataset Gold
# 2. Análisis del target
# 3. Cobertura temporal y de aeropuertos
# 4. Variables operacionales
# 5. Variables de tráfico origen-destino
# 6. Variables meteorológicas
# 7. EDA geográfico del dataset mensual aeroportuario
# 8. Correlaciones con el target

# %% [markdown]
# ## 0. Imports y configuración

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.patches as mpatches
import seaborn as sns
from pathlib import Path
from pyspark.sql import functions as F
import plotly.express as px
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', '{:,.2f}'.format)

# Estilo general de gráficos
sns.set_theme(style='whitegrid', palette='muted', font_scale=1.1)
FIGSIZE_STD  = (12, 5)
FIGSIZE_WIDE = (16, 6)
FIGSIZE_SQ   = (10, 8)

TARGET_COL    = 'target_nivel_operacion_mes_siguiente'
TARGET_ORDER  = ['bajo', 'medio', 'alto']
PALETTE_TARGET = {'bajo': '#4878CF', 'medio': '#6ACC65', 'alto': '#D65F5F'}

print('Imports OK')
# Out:
# Imports OK

# %% [markdown]
# ## 1. Carga del dataset Gold

# %%
BASE_DIR = Path("/Volumes/workspace/default/proyecto_aeropuertos")
GOLD_MONTHLY_DIR = BASE_DIR / "gold" / "monthly_airport_dataset"

def read_parquet_pandas(path: Path) -> pd.DataFrame:
    """
    Lee Parquet con pandas.

    Soporta:
    1. Parquet tipo archivo único generado por pandas.
    2. Parquet tipo carpeta generado por Spark:
       archivo.parquet/
       ├── part-00000-...
       ├── part-00001-...
       └── _SUCCESS
    """
    path = Path(path)

    if not path.exists():
        raise FileNotFoundError(f"No existe el path: {path}")

    try:
        return pd.read_parquet(path, engine="pyarrow")
    except Exception as exc:
        print(f"[WARN] pd.read_parquet directo falló: {exc}")
        print("[INFO] Intentando leer part-files internos...")

        part_files = sorted(path.glob("part-*.parquet"))

        if not part_files:
            raise RuntimeError(f"No se encontraron part-files en: {path}")

        return pd.concat(
            [pd.read_parquet(part_file, engine="pyarrow") for part_file in part_files],
            ignore_index=True,
        )


df_full = read_parquet_pandas(
    GOLD_MONTHLY_DIR / "monthly_airport_dataset.parquet"
)

df = read_parquet_pandas(
    GOLD_MONTHLY_DIR / "monthly_airport_model_dataset.parquet"
)

df_full["fecha_mes"] = pd.to_datetime(df_full["fecha_mes"])
df["fecha_mes"] = pd.to_datetime(df["fecha_mes"])

print(f"Dataset completo : {df_full.shape[0]:,} filas x {df_full.shape[1]:,} columnas")
print(f"Dataset modelado : {df.shape[0]:,} filas x {df.shape[1]:,} columnas")
print(f"Período          : {df['fecha_mes'].min().strftime('%Y-%m')} → {df['fecha_mes'].max().strftime('%Y-%m')}")
print(f"Aeropuertos únicos: {df['icao_code'].nunique()}")
# Out:
# Dataset completo : 3,300 filas x 63 columnas
# Dataset modelado : 3,254 filas x 66 columnas
# Período          : 2020-01 → 2025-11
# Aeropuertos únicos: 46

# %%
df.head(5)
# Out:
#   icao_code  fecha_mes  operaciones_llegada  operaciones_salida  \
# 0      SKAR 2020-01-01               408.00              409.00
# 1      SKAR 2020-02-01               372.00              372.00
# 2      SKAR 2020-03-01               265.00              266.00
# 3      SKAR 2020-04-01                11.00               10.00
# 4      SKAR 2020-05-01                18.00               13.00
#
#    TOQUE Y DESPEGUE  operaciones_otras  operaciones_total  pasajeros_salida  \
# 0              0.00               0.00             817.00         25,548.00
# 1              0.00               0.00             744.00         22,490.00
# 2              0.00               0.00             531.00         13,541.00
# 3              0.00               0.00              21.00              0.00
# 4              0.00               0.00              31.00              0.00
#
#    carga_salida_kg  n_destinos_total  n_empresas_salida  n_registros_salida  \
# 0           119.00                73                  5                  85
# 1           182.00                66                  6                  76
# 2         4,170.00                69                  7                  82
# 3        17,216.00                 3                  1                   3
# 4         7,891.00                 2                  2                   2
#
#    pasajeros_llegada  carga_llegada_kg  n_origenes_total  n_empresas_llegada  \
# 0          22,854.00              0.00                71                   5
# 1          22,022.00            130.00                71                   6
# 2          13,241.00          3,660.00                67                   7
# 3               0.00         16,709.00                 2                   1
# 4               0.00          6,061.00                 2                   2
#
#    n_registros_llegada  pasajeros_total  carga_total_kg  \
# 0                   85        48,402.00          119.00
# 1                   82        44,512.00          312.00
# 2                   87        26,782.00        7,830.00
# 3                    2             0.00       33,925.00
# 4                    2             0.00       13,952.00
#
#    pasajeros_salida_internacional  pasajeros_salida_nacional  \
# 0                        4,448.00                  21,100.00
# 1                        3,206.00                  19,284.00
# 2                        1,975.00                  11,566.00
# 3                            0.00                       0.00
# 4                            0.00                       0.00
#
#    pasajeros_llegada_internacional  pasajeros_llegada_nacional  \
# 0                         3,880.00                   18,974.00
# 1                         2,930.00                   19,092.00
# 2                         1,580.00                   11,661.00
# 3                             0.00                        0.00
# 4                             0.00                        0.00
#
#    pasajeros_internacional_total  proporcion_pasajeros_internacional  \
# 0                       8,328.00                                0.17
# 1                       6,136.00                                0.14
# 2                       3,555.00                                0.13
# 3                           0.00                                0.00
# 4                           0.00                                0.00
#
#    n_metar_mes  temp_media_c  temp_min_c  temp_max_c  temp_std_c  \
# 0          573         23.65       15.00       33.00        4.33
# 1          508         23.82       16.00       34.00        4.36
# 2          525         23.27       15.00       30.00        3.24
# 3          277         24.25       18.00       31.00        3.15
# 4          208         25.41       20.00       32.00        2.79
#
#    dewpoint_media_c  humedad_media_pct  viento_medio_kt  viento_max_kt  \
# 0             18.79              76.98             1.20          12.00
# 1             18.88              76.77             1.27          13.00
# 2             18.00              74.21             1.55          14.00
# 3             19.52              76.48             1.74           9.00
# 4             20.29              74.47             1.33           8.00
#
#    viento_std_kt  rafaga_max_kt  visibilidad_media_sm  visibilidad_min_sm  \
# 0           1.98            NaN                  5.81                0.62
# 1           2.05            NaN                  5.63                0.19
# 2           2.32            NaN                  5.67                0.12
# 3           2.36            NaN                  5.64                0.19
# 4           1.97            NaN                  5.91                1.24
#
#    visibilidad_std_sm  cloud_base_min_ft  altimeter_media_inhg  prop_lluvia  \
# 0                1.06             600.00                 30.04         0.11
# 1                1.31             300.00                 30.02         0.13
# 2                1.17             800.00                 30.03         0.12
# 3                1.30             200.00                 30.07         0.17
# 4                0.89             800.00                 30.07         0.12
#
#    prop_tormenta  prop_niebla  prop_baja_visibilidad  prop_viento_fuerte  \
# 0           0.01         0.05                   0.05                0.00
# 1           0.03         0.10                   0.06                0.00
# 2           0.02         0.12                   0.06                0.00
# 3           0.04         0.06                   0.05                0.00
# 4           0.00         0.06                   0.03                0.00
#
#    prop_rafaga  prop_ifr_aprox  n_metar_esperados_mes  cobertura_metar_ratio  \
# 0         0.00            0.05                 744.00                   0.77
# 1         0.00            0.07                 696.00                   0.73
# 2         0.00            0.07                 744.00                   0.71
# 3         0.00            0.08                 720.00                   0.38
# 4         0.00            0.04                 744.00                   0.28
#
#               name            type municipality         region_name iata_code  \
# 0  El Eden Airport  medium_airport      Armenia  Quindio Department       AXM
# 1  El Eden Airport  medium_airport      Armenia  Quindio Department       AXM
# 2  El Eden Airport  medium_airport      Armenia  Quindio Department       AXM
# 3  El Eden Airport  medium_airport      Armenia  Quindio Department       AXM
# 4  El Eden Airport  medium_airport      Armenia  Quindio Department       AXM
#
#   latitude_deg longitude_deg elevation_ft scheduled_service  tiene_metar_mes  \
# 0      4.45278      -75.7664         3990                 1                1
# 1      4.45278      -75.7664         3990                 1                1
# 2      4.45278      -75.7664         3990                 1                1
# 3      4.45278      -75.7664         3990                 1                1
# 4      4.45278      -75.7664         3990                 1                1
#
#    tiene_od_mes  sin_od_sin_metar_mes  target_operaciones_total_mes_siguiente  \
# 0             1                     0                                  744.00
# 1             1                     0                                  531.00
# 2             1                     0                                   21.00
# 3             1                     0                                   31.00
# 4             1                     0                                   12.00
#
#    target_q33_operaciones  target_q66_operaciones  \
# 0                  220.00                  564.00
# 1                  220.00                  564.00
# 2                  220.00                  564.00
# 3                  220.00                  564.00
# 4                  220.00                  564.00
#
#   target_nivel_operacion_mes_siguiente
# 0                                 alto
# 1                                medio
# 2                                 bajo
# 3                                 bajo
# 4                                 bajo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3254 entries, 0 to 3253
# Data columns (total 66 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   icao_code                               3254 non-null   object
#  1   fecha_mes                               3254 non-null   datetime64[ns]
#  2   operaciones_llegada                     3254 non-null   float64
#  3   operaciones_salida                      3254 non-null   float64
#  4   TOQUE Y DESPEGUE                        3254 non-null   float64
#  5   operaciones_otras                       3254 non-null   float64
#  6   operaciones_total                       3254 non-null   float64
#  7   pasajeros_salida                        3254 non-null   float64
#  8   carga_salida_kg                         3254 non-null   float64
#  9   n_destinos_total                        3254 non-null   int64
#  10  n_empresas_salida                       3254 non-null   int64
#  11  n_registros_salida                      3254 non-null   int64
#  12  pasajeros_llegada                       3254 non-null   float64
#  13  carga_llegada_kg                        3254 non-null   float64
#  14  n_origenes_total                        3254 non-null   int64
#  15  n_empresas_llegada                      3254 non-null   int64
#  16  n_registros_llegada                     3254 non-null   int64
#  17  pasajeros_total                         3254 non-null   float64
#  18  carga_total_kg                          3254 non-null   float64
#  19  pasajeros_salida_internacional          3105 non-null   float64
#  20  pasajeros_salida_nacional               3105 non-null   float64
#  21  pasajeros_llegada_internacional         3105 non-null   float64
#  22  pasajeros_llegada_nacional              3105 non-null   float64
#  23  pasajeros_internacional_total           3254 non-null   float64
#  24  proporcion_pasajeros_internacional      3254 non-null   float64
#  25  n_metar_mes                             3254 non-null   int64
#  26  temp_media_c                            2440 non-null   float64
#  27  temp_min_c                              2440 non-null   float64
#  28  temp_max_c                              2440 non-null   float64
#  29  temp_std_c                              2284 non-null   float64
#  30  dewpoint_media_c                        2437 non-null   float64
#  31  humedad_media_pct                       2436 non-null   float64
#  32  viento_medio_kt                         2442 non-null   float64
#  33  viento_max_kt                           2442 non-null   float64
#  34  viento_std_kt                           2282 non-null   float64
#  35  rafaga_max_kt                           1070 non-null   float64
#  36  visibilidad_media_sm                    2442 non-null   float64
#  37  visibilidad_min_sm                      2442 non-null   float64
#  38  visibilidad_std_sm                      2286 non-null   float64
#  39  cloud_base_min_ft                       2425 non-null   float64
#  40  altimeter_media_inhg                    2441 non-null   float64
#  41  prop_lluvia                             2444 non-null   float64
#  42  prop_tormenta                           2444 non-null   float64
#  43  prop_niebla                             2444 non-null   float64
#  44  prop_baja_visibilidad                   2442 non-null   float64
#  45  prop_viento_fuerte                      2442 non-null   float64
#  46  prop_rafaga                             2444 non-null   float64
#  47  prop_ifr_aprox                          2424 non-null   float64
#  48  n_metar_esperados_mes                   2444 non-null   float64
#  49  cobertura_metar_ratio                   2444 non-null   float64
#  50  name                                    3254 non-null   object
#  51  type                                    3254 non-null   object
#  52  municipality                            3254 non-null   object
#  53  region_name                             3254 non-null   object
#  54  iata_code                               3254 non-null   object
#  55  latitude_deg                            3254 non-null   object
#  56  longitude_deg                           3254 non-null   object
#  57  elevation_ft                            3254 non-null   object
#  58  scheduled_service                       3254 non-null   object
#  59  tiene_metar_mes                         3254 non-null   int32
#  60  tiene_od_mes                            3254 non-null   int32
#  61  sin_od_sin_metar_mes                    3254 non-null   int32
#  62  target_operaciones_total_mes_siguiente  3254 non-null   float64
#  63  target_q33_operaciones                  3254 non-null   float64
#  64  target_q66_operaciones                  3254 non-null   float64
#  65  target_nivel_operacion_mes_siguiente    3254 non-null   object
# dtypes: datetime64[ns](1), float64(44), int32(3), int64(7), object(11)
# memory usage: 1.6+ MB

# %%
cols_desc = [
    'operaciones_total', 'operaciones_llegada', 'operaciones_salida',
    'pasajeros_total', 'carga_total_kg',
    'temp_media_c', 'humedad_media_pct', 'viento_medio_kt',
    'visibilidad_media_sm', 'prop_lluvia', 'prop_tormenta',
    'target_operaciones_total_mes_siguiente'
]
df[cols_desc].describe().T.round(2)
# Out:
#                                           count         mean          std  \
# operaciones_total                      3,254.00     1,474.92     3,905.57
# operaciones_llegada                    3,254.00       727.22     1,955.77
# operaciones_salida                     3,254.00       727.16     1,952.38
# pasajeros_total                        3,254.00   124,075.71   398,143.63
# carga_total_kg                         3,254.00 1,796,552.81 9,109,196.47
# temp_media_c                           2,440.00        25.16         4.68
# humedad_media_pct                      2,436.00        77.94        10.10
# viento_medio_kt                        2,442.00         4.76         2.39
# visibilidad_media_sm                   2,442.00         5.81         0.60
# prop_lluvia                            2,444.00         0.13         0.15
# prop_tormenta                          2,444.00         0.02         0.04
# target_operaciones_total_mes_siguiente 3,254.00     1,476.23     3,919.83
#
#                                          min      25%       50%        75%  \
# operaciones_total                       1.00   198.00    464.50   1,094.50
# operaciones_llegada                     0.00    97.00    215.00     518.00
# operaciones_salida                      0.00    98.00    218.00     516.00
# pasajeros_total                         0.00 2,614.00 11,578.50  57,842.25
# carga_total_kg                          0.00 2,233.00 39,169.50 216,618.00
# temp_media_c                            9.00    23.00     26.62      28.42
# humedad_media_pct                      35.32    72.85     79.44      84.49
# viento_medio_kt                         0.00     3.26      4.38       5.65
# visibilidad_media_sm                    0.06     5.71      6.01       6.14
# prop_lluvia                             0.00     0.03      0.09       0.17
# prop_tormenta                           0.00     0.00      0.01       0.02
# target_operaciones_total_mes_siguiente  1.00   197.25    462.00   1,080.75
#
#                                                  max
# operaciones_total                          32,767.00
# operaciones_llegada                        16,373.00
# operaciones_salida                         16,394.00
# pasajeros_total                         3,552,349.00
# carga_total_kg                         76,516,003.00
# temp_media_c                                   35.00
# humedad_media_pct                             100.00
# viento_medio_kt                                16.00
# visibilidad_media_sm                            6.21
# prop_lluvia                                     1.00
# prop_tormenta                                   1.00
# target_operaciones_total_mes_siguiente     34,357.00

# %% [markdown]
# ## 2. Análisis del target

# %% [markdown]
# ### 2.1 Distribución de clases

# %%
conteo_target = df[TARGET_COL].value_counts().reindex(TARGET_ORDER)
pct_target    = (conteo_target / conteo_target.sum() * 100).round(1)

fig, axes = plt.subplots(1, 2, figsize=FIGSIZE_STD)

axes[0].bar(TARGET_ORDER, conteo_target.values,
            color=[PALETTE_TARGET[c] for c in TARGET_ORDER], edgecolor='white', linewidth=0.8)
for i, (n, p) in enumerate(zip(conteo_target.values, pct_target.values)):
    axes[0].text(i, n + 30, f'{n:,}\n({p}%)', ha='center', va='bottom', fontsize=10)
axes[0].set_title('Distribución del target (conteo)', fontweight='bold')
axes[0].set_xlabel('Nivel de operación')
axes[0].set_ylabel('Número de registros')
axes[0].set_ylim(0, conteo_target.max() * 1.18)

axes[1].pie(conteo_target.values, labels=TARGET_ORDER, autopct='%1.1f%%',
            colors=[PALETTE_TARGET[c] for c in TARGET_ORDER],
            startangle=90, wedgeprops={'edgecolor': 'white', 'linewidth': 1.5})
axes[1].set_title('Proporción del target', fontweight='bold')

plt.suptitle('Balance de clases — target_nivel_operacion_mes_siguiente',
             fontsize=13, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print('\nBalance de clases:')
print(pd.DataFrame({'n': conteo_target, '%': pct_target}))
# Out:
# Balance de clases:
#           n     %
# bajo   1072 32.90
# medio  1077 33.10
# alto   1105 34.00

# %% [markdown]
# ### 2.2 Distribución numérica del target + umbrales

# %%
# Umbrales son POR AEROPUERTO — se muestra la mediana como referencia visual
q33_mediana = df['target_q33_operaciones'].median()
q66_mediana = df['target_q66_operaciones'].median()

fig, axes = plt.subplots(1, 2, figsize=FIGSIZE_STD)

# Histograma con umbrales de referencia
axes[0].hist(df['target_operaciones_total_mes_siguiente'].dropna(),
             bins=60, color='#4878CF', edgecolor='white', linewidth=0.5)
axes[0].axvline(q33_mediana, color='#6ACC65', linestyle='--', linewidth=2,
                label=f'P33 mediana por aeropuerto: {q33_mediana:,.0f}')
axes[0].axvline(q66_mediana, color='#D65F5F', linestyle='--', linewidth=2,
                label=f'P66 mediana por aeropuerto: {q66_mediana:,.0f}')
axes[0].set_title('Distribución de operaciones (mes siguiente)\ncon umbrales de clasificación',
                  fontweight='bold')
axes[0].set_xlabel('Total operaciones')
axes[0].set_ylabel('Frecuencia')
axes[0].legend(fontsize=9)

# Boxplot por clase con escala logarítmica
data_by_class = [
    df[df[TARGET_COL] == c]['target_operaciones_total_mes_siguiente'].dropna().values
    for c in TARGET_ORDER
]
bp = axes[1].boxplot(data_by_class, labels=TARGET_ORDER, patch_artist=True,
                     medianprops={'color': 'white', 'linewidth': 2})
for patch, color in zip(bp['boxes'], [PALETTE_TARGET[c] for c in TARGET_ORDER]):
    patch.set_facecolor(color)
    patch.set_alpha(0.8)

axes[1].set_yscale('log')  # ← escala log para separar las cajas
axes[1].set_title('Operaciones por clase del target', fontweight='bold')
axes[1].set_xlabel('Nivel de operación (mes siguiente)')
axes[1].set_ylabel('Total operaciones mes siguiente (escala log)')

plt.tight_layout()
plt.show()

print(f'Umbral bajo  → medio : {q33_mediana:,.0f} operaciones (mediana por aeropuerto)')
print(f'Umbral medio → alto  : {q66_mediana:,.0f} operaciones (mediana por aeropuerto)')
print(f'\nRango P33 por aeropuerto: {df["target_q33_operaciones"].min():,.0f} — {df["target_q33_operaciones"].max():,.0f}')
print(f'Rango P66 por aeropuerto: {df["target_q66_operaciones"].min():,.0f} — {df["target_q66_operaciones"].max():,.0f}')
print(f'\nBalance de clases:')
print(df[TARGET_COL].value_counts().reindex(TARGET_ORDER))
# Out:
# Umbral bajo  → medio : 220 operaciones (mediana por aeropuerto)
# Umbral medio → alto  : 564 operaciones (mediana por aeropuerto)
#
# Rango P33 por aeropuerto: 220 — 2,564
# Rango P66 por aeropuerto: 539 — 4,971
#
# Balance de clases:
# bajo     1072
# medio    1077
# alto     1105
# Name: target_nivel_operacion_mes_siguiente, dtype: int64

# %% [markdown]
# ## 3. Cobertura temporal y de aeropuertos

# %% [markdown]
# ### 3.1 Aeropuertos por tipo

# %%
tipo_counts = df.drop_duplicates('icao_code')['type'].value_counts()
print('Aeropuertos únicos en el dataset de modelado:')
print(tipo_counts.to_string())
print(f'\nTotal: {df["icao_code"].nunique()} aeropuertos')
# Out:
# Aeropuertos únicos en el dataset de modelado:
# medium_airport    38
# large_airport      6
# small_airport      2
#
# Total: 46 aeropuertos

# %% [markdown]
# ### 3.2 Heatmap cobertura temporal — Top 40 aeropuertos

# %%
top_icaos = (df.groupby('icao_code')['operaciones_total']
               .sum().nlargest(40).index.tolist())

pivot_cob = (
    df[df['icao_code'].isin(top_icaos)]
    .assign(anio_mes=lambda x: x['fecha_mes'].dt.to_period('M').astype(str))
    .pivot_table(index='icao_code', columns='anio_mes',
                 values='operaciones_total', aggfunc='sum')
    .fillna(0)
    .loc[top_icaos]
)

fig, ax = plt.subplots(figsize=(18, 10))
sns.heatmap(pivot_cob, cmap='YlOrRd', linewidths=0.3, linecolor='#f0f0f0',
            ax=ax, cbar_kws={'label': 'Operaciones totales'})
ax.set_title('Cobertura temporal — Top 40 aeropuertos por operaciones',
             fontweight='bold', fontsize=13)
ax.set_xlabel('Año-Mes')
ax.set_ylabel('Aeropuerto (ICAO)')
for i, label in enumerate(ax.get_xticklabels()):
    if i % 6 != 0:
        label.set_visible(False)
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 Registros por año

# %%
registros_anio = df.groupby(df['fecha_mes'].dt.year).size().reset_index(name='n_registros')
registros_anio.columns = ['anio', 'n_registros']

fig, ax = plt.subplots(figsize=(10, 4))
ax.bar(registros_anio['anio'].astype(str), registros_anio['n_registros'],
       color='#4878CF', edgecolor='white')
for idx, (_, row) in enumerate(registros_anio.iterrows()):
    ax.text(idx, row['n_registros'] + 10, f"{row['n_registros']:,}",
            ha='center', va='bottom', fontsize=9)
ax.set_title('Registros aeropuerto-mes por año', fontweight='bold')
ax.set_xlabel('Año')
ax.set_ylabel('N° registros')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.4 Distribución del target por año (¿se mantiene el balance?)

# %%
target_anio = (
    df.assign(anio=df['fecha_mes'].dt.year)
    .groupby(['anio', TARGET_COL])
    .size()
    .reset_index(name='n')
)

fig, axes = plt.subplots(1, 2, figsize=FIGSIZE_WIDE)

# Absoluto
for nivel in TARGET_ORDER:
    sub = target_anio[target_anio[TARGET_COL] == nivel]
    axes[0].plot(sub['anio'], sub['n'], marker='o', label=nivel,
                color=PALETTE_TARGET[nivel], linewidth=2)
axes[0].set_title('Distribución absoluta del target por año', fontweight='bold')
axes[0].set_xlabel('Año')
axes[0].set_ylabel('N° registros')
axes[0].legend(title='Nivel')
axes[0].xaxis.set_major_locator(mticker.MultipleLocator(1))

# Proporcional — para ver si el balance se mantiene
target_anio_pct = (
    target_anio.copy()
    .assign(total=lambda d: d.groupby('anio')['n'].transform('sum'))
    .assign(pct=lambda d: d['n'] / d['total'] * 100)
)
bottom = np.zeros(target_anio_pct['anio'].nunique())
anios  = sorted(target_anio_pct['anio'].unique())
x      = np.arange(len(anios))
for nivel in TARGET_ORDER:
    vals = []
    for a in anios:
        sub = target_anio_pct[
            (target_anio_pct['anio'] == a) &
            (target_anio_pct[TARGET_COL] == nivel)
        ]['pct'].values
        vals.append(sub[0] if len(sub) > 0 else 0.0)
    axes[1].bar(x, vals, bottom=bottom, label=nivel,
                color=PALETTE_TARGET[nivel], edgecolor='white')
    bottom += np.array(vals)
axes[1].set_xticks(x)
axes[1].set_xticklabels([str(a) for a in anios])
axes[1].set_title('Proporción del target por año (stacked)', fontweight='bold')
axes[1].set_xlabel('Año')
axes[1].set_ylabel('% registros')
axes[1].legend(title='Nivel')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Variables operacionales

# %% [markdown]
# ### 4.1 Top 15 aeropuertos por operaciones totales acumuladas

# %%
top15_ops  = (df.groupby('icao_code')['operaciones_total']
                .sum().nlargest(15).sort_values(ascending=True))
nombre_map = df.drop_duplicates('icao_code').set_index('icao_code')['name'].to_dict()
labels     = [f"{icao} · {str(nombre_map.get(icao, ''))[:22]}" for icao in top15_ops.index]

fig, ax = plt.subplots(figsize=(11, 7))
bars = ax.barh(labels, top15_ops.values, color='#4878CF', edgecolor='white')
for bar, val in zip(bars, top15_ops.values):
    ax.text(val + 200, bar.get_y() + bar.get_height()/2,
            f'{val:,.0f}', va='center', fontsize=9)
ax.set_title('Top 15 aeropuertos — operaciones totales acumuladas 2020-2025',
             fontweight='bold')
ax.set_xlabel('Operaciones acumuladas')
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  4.2 Evolución mensual total + impacto COVID

# %%
ops_tiempo = df.groupby('fecha_mes')['operaciones_total'].sum().reset_index()

fig, ax = plt.subplots(figsize=FIGSIZE_WIDE)
ax.fill_between(ops_tiempo['fecha_mes'], ops_tiempo['operaciones_total'],
                alpha=0.25, color='#4878CF')
ax.plot(ops_tiempo['fecha_mes'], ops_tiempo['operaciones_total'],
        color='#4878CF', linewidth=1.8)
ax.axvspan(pd.Timestamp('2020-03-01'), pd.Timestamp('2020-09-01'),
           alpha=0.15, color='red', label='Restricciones COVID')
# Anotar el mínimo
min_idx = ops_tiempo['operaciones_total'].idxmin()
min_row = ops_tiempo.loc[min_idx]
ax.annotate(f"Mínimo COVID\n{min_row['operaciones_total']:,.0f}",
            xy=(min_row['fecha_mes'], min_row['operaciones_total']),
            xytext=(min_row['fecha_mes'], min_row['operaciones_total'] + ops_tiempo['operaciones_total'].max()*0.1),
            arrowprops=dict(arrowstyle='->', color='red'), color='red', fontsize=9, ha='center')
ax.set_title('Evolución mensual — operaciones totales (todos los aeropuertos)',
             fontweight='bold')
ax.set_xlabel('Mes')
ax.set_ylabel('Operaciones totales')
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  4.3 Distribución de operaciones_total por clase del target

# %%
fig, axes = plt.subplots(1, 3, figsize=FIGSIZE_WIDE, sharey=False)
for ax, nivel in zip(axes, TARGET_ORDER):
    datos = df[df[TARGET_COL] == nivel]['operaciones_total']
    ax.hist(datos, bins=40, color=PALETTE_TARGET[nivel], edgecolor='white', linewidth=0.5)
    ax.set_title(f'Nivel: {nivel}', fontweight='bold')
    ax.set_xlabel('operaciones_total (mes actual)')
    ax.set_ylabel('Frecuencia')
    ax.axvline(datos.median(), color='black', linestyle='--', linewidth=1.5,
               label=f'Mediana: {datos.median():,.0f}')
    ax.legend(fontsize=9)
plt.suptitle('Distribución de operaciones actuales por clase del target',
             fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  4.4 Proporción llegadas vs salidas + concentración por aeropuerto

# %%
fig, axes = plt.subplots(1, 2, figsize=FIGSIZE_STD)

df_ops = df.copy()
df_ops['prop_llegadas'] = df_ops['operaciones_llegada'] / (df_ops['operaciones_total'] + 1e-9)

axes[0].hist(df_ops['prop_llegadas'], bins=40, color='#6ACC65', edgecolor='white')
axes[0].axvline(0.5, color='red', linestyle='--', label='50% llegadas')
axes[0].set_title('Proporción de llegadas sobre total de operaciones', fontweight='bold')
axes[0].set_xlabel('Proporción llegadas')
axes[0].set_ylabel('Frecuencia')
axes[0].legend()

# Curva de Lorenz-style: concentración de operaciones por aeropuerto
ops_por_aeropuerto = df.groupby('icao_code')['operaciones_total'].sum().sort_values()
total = ops_por_aeropuerto.sum()
cumsum = ops_por_aeropuerto.cumsum() / total * 100
x_pct  = np.linspace(0, 100, len(cumsum))
axes[1].plot(x_pct, cumsum.values, color='#4878CF', linewidth=2)
axes[1].plot([0, 100], [0, 100], 'k--', linewidth=1, label='Distribución uniforme')
axes[1].fill_between(x_pct, cumsum.values, x_pct, alpha=0.2, color='#4878CF')
axes[1].set_title('Concentración de operaciones por aeropuerto\n(curva de Lorenz)', fontweight='bold')
axes[1].set_xlabel('% aeropuertos (acumulado, menor→mayor)')
axes[1].set_ylabel('% operaciones acumuladas')
axes[1].legend()

# Mostrar % que concentra el top 10%
top10_idx = int(len(ops_por_aeropuerto) * 0.9)
pct_top10 = 100 - cumsum.iloc[top10_idx]
axes[1].annotate(f'Top 10% aeropuertos\n= {pct_top10:.1f}% de operaciones',
                 xy=(90, cumsum.iloc[top10_idx]), xytext=(60, 40),
                 arrowprops=dict(arrowstyle='->', color='#D65F5F'), color='#D65F5F', fontsize=9)
plt.tight_layout()
plt.show()
print(f'Mediana proporción llegadas: {df_ops["prop_llegadas"].median():.3f}')
# Out:
# Mediana proporción llegadas: 0.499

# %% [markdown]
# ## 5. Variables de tráfico origen-destino

# %% [markdown]
# ###  5.1 Pasajeros totales: evolución mensual

# %%
pax_tiempo = df.groupby('fecha_mes')['pasajeros_total'].sum().reset_index()

fig, ax = plt.subplots(figsize=FIGSIZE_WIDE)
ax.fill_between(pax_tiempo['fecha_mes'], pax_tiempo['pasajeros_total'],
                alpha=0.25, color='green')
ax.plot(pax_tiempo['fecha_mes'], pax_tiempo['pasajeros_total'],
        color='green', linewidth=1.8)

# Marca COVID
ax.axvspan(pd.Timestamp('2020-03-01'), pd.Timestamp('2020-09-01'),
           alpha=0.18, color='red', label='Restricciones COVID')
ax.axvline(pd.Timestamp('2020-03-01'), color='red', linewidth=1, linestyle='--', alpha=0.6)

# Anotación en el mínimo
min_idx = pax_tiempo['pasajeros_total'].idxmin()
min_row = pax_tiempo.loc[min_idx]
max_val = pax_tiempo['pasajeros_total'].max()
ax.annotate(f"Mínimo COVID\n{min_row['pasajeros_total']/1e6:.2f}M",
            xy=(min_row['fecha_mes'], min_row['pasajeros_total']),
            xytext=(min_row['fecha_mes'], min_row['pasajeros_total'] + max_val * 0.12),
            arrowprops=dict(arrowstyle='->', color='red'), color='red', fontsize=9, ha='center')

ax.set_title('Evolución mensual — pasajeros totales (todos los aeropuertos)', fontweight='bold')
ax.set_xlabel('Mes')
ax.set_ylabel('Pasajeros')
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x/1e6:.1f}M'))
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  5.2 Pasajeros y conectividad por clase del target

# %%
fig, axes = plt.subplots(1, 2, figsize=FIGSIZE_STD)

for ax, col, titulo in zip(axes,
    ['pasajeros_total', 'n_destinos_total'],
    ['Pasajeros totales (sin outliers extremos)', 'Número de destinos distintos']):
    data_by_c = [df[df[TARGET_COL] == c][col].dropna().values for c in TARGET_ORDER]
    bp = ax.boxplot(data_by_c, labels=TARGET_ORDER, patch_artist=True,
                    medianprops={'color': 'white', 'linewidth': 2}, showfliers=False)
    for patch, color in zip(bp['boxes'], [PALETTE_TARGET[c] for c in TARGET_ORDER]):
        patch.set_facecolor(color)
        patch.set_alpha(0.8)
    ax.set_title(titulo, fontweight='bold')
    ax.set_xlabel('Nivel de operación (mes siguiente)')

axes[0].yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.suptitle('Pasajeros y conectividad por clase del target', fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  5.3 Proporción de pasajeros internacionales

# %%
fig, axes = plt.subplots(1, 2, figsize=FIGSIZE_STD)

axes[0].hist(df['proporcion_pasajeros_internacional'].dropna(),
             bins=40, color='#8172B2', edgecolor='white')
axes[0].set_title('Distribución proporción pasajeros internacionales', fontweight='bold')
axes[0].set_xlabel('Proporción internacional')
axes[0].set_ylabel('Frecuencia')
axes[0].axvline(df['proporcion_pasajeros_internacional'].median(), color='navy',
                linestyle='--', label=f'Mediana: {df["proporcion_pasajeros_internacional"].median():.3f}')
axes[0].legend()

medias = df.groupby(TARGET_COL)['proporcion_pasajeros_internacional'].mean().reindex(TARGET_ORDER)
axes[1].bar(TARGET_ORDER, medias.values,
            color=[PALETTE_TARGET[c] for c in TARGET_ORDER], edgecolor='white')
axes[1].set_title('Proporción internacional media por clase', fontweight='bold')
axes[1].set_xlabel('Nivel de operación (mes siguiente)')
axes[1].set_ylabel('Proporción media')
for i, v in enumerate(medias.values):
    axes[1].text(i, v + 0.005, f'{v:.3f}', ha='center', fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Variables meteorológicas

# %% [markdown]
# ###  6.1 Cobertura METAR — 3 grupos visualizados explícitamente

# %%
cobertura_metar = (
    df.groupby('icao_code')['tiene_metar_mes']
    .mean()
    .sort_values(ascending=False)
)

# Definir grupos
def grupo_metar(p):
    if p == 1.0: return 'Cobertura perfecta (100%)'
    elif p >= 0.5: return 'Cobertura parcial (≥50%)'
    elif p > 0.0:  return 'Cobertura baja (<50%)'
    else:          return 'Sin METAR (0%)'

grupo_colors = {
    'Cobertura perfecta (100%)':  '#2ecc71',
    'Cobertura parcial (≥50%)':   '#f39c12',
    'Cobertura baja (<50%)':      '#e67e22',
    'Sin METAR (0%)':             '#c0392b',
}

grupos = cobertura_metar.apply(grupo_metar)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Barras individuales coloreadas por grupo
bar_colors = [grupo_colors[grupos[icao]] for icao in cobertura_metar.index]
axes[0].bar(range(len(cobertura_metar)), cobertura_metar.values,
            color=bar_colors, edgecolor='none', width=1.0)
axes[0].axhline(0.8, color='black', linestyle='--', linewidth=1, label='Umbral 80%')
axes[0].set_title('Proporción de meses con METAR por aeropuerto\n(coloreado por grupo)',
                  fontweight='bold')
axes[0].set_xlabel('Aeropuerto (ordenado por cobertura)')
axes[0].set_ylabel('Proporción meses con METAR')
axes[0].set_xticks([])
patches = [mpatches.Patch(color=c, label=l) for l, c in grupo_colors.items()]
axes[0].legend(handles=patches, fontsize=9)

# Conteo por grupo
conteo_grupos = grupos.value_counts()
order_grupos  = list(grupo_colors.keys())
conteo_plot   = [conteo_grupos.get(g, 0) for g in order_grupos]
bars = axes[1].barh(order_grupos, conteo_plot,
                    color=[grupo_colors[g] for g in order_grupos], edgecolor='white')
for bar, val in zip(bars, conteo_plot):
    axes[1].text(val + 1, bar.get_y() + bar.get_height()/2,
                 str(val), va='center', fontsize=11, fontweight='bold')
axes[1].set_title('Número de aeropuertos por nivel de cobertura METAR',
                  fontweight='bold')
axes[1].set_xlabel('Número de aeropuertos')
axes[1].set_xlim(0, max(conteo_plot) * 1.15)

plt.tight_layout()
plt.show()

n_con_metar = (cobertura_metar > 0).sum()
print(f'Aeropuertos con al menos 1 mes con METAR : {n_con_metar} / {len(cobertura_metar)}')
print(f'Aeropuertos con cobertura perfecta (100%): {(cobertura_metar == 1.0).sum()}')
print(f'Sin ningún mes con METAR                 : {(cobertura_metar == 0).sum()}')
# Out:
# Aeropuertos con al menos 1 mes con METAR : 46 / 46
# Aeropuertos con cobertura perfecta (100%): 12
# Sin ningún mes con METAR                 : 0

# %% [markdown]
# ###  6.2 Distribuciones de variables meteorológicas clave

# %%
vars_meteo = [
    ('temp_media_c',         'Temperatura media (°C)'),
    ('humedad_media_pct',    'Humedad media (%)'),
    ('viento_medio_kt',      'Viento medio (kt)'),
    ('visibilidad_media_sm', 'Visibilidad media (sm)'),
    ('prop_lluvia',          'Proporción obs. con lluvia'),
    ('prop_tormenta',        'Proporción obs. con tormenta'),
]

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
for ax, (col, label) in zip(axes.flatten(), vars_meteo):
    data = df[col].dropna()
    ax.hist(data, bins=40, color='#6ACC65', edgecolor='white', linewidth=0.5)
    ax.axvline(data.mean(),   color='red',  linestyle='--', linewidth=1.5,
               label=f'Media: {data.mean():.2f}')
    ax.axvline(data.median(), color='navy', linestyle=':',  linewidth=1.5,
               label=f'Mediana: {data.median():.2f}')
    ax.set_title(label, fontweight='bold', fontsize=10)
    ax.legend(fontsize=8)
    ax.set_ylabel('Frecuencia')
    # Porcentaje de nulos
    pct_null = df[col].isnull().mean() * 100
    ax.text(0.98, 0.95, f'NaN: {pct_null:.1f}%', transform=ax.transAxes,
            ha='right', va='top', fontsize=8, color='gray')

plt.suptitle('Distribuciones de variables meteorológicas', fontweight='bold', fontsize=13, y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  6.3 Variables meteorológicas por clase del target

# %%
vars_meteo_box = ['temp_media_c', 'humedad_media_pct', 'viento_medio_kt',
                  'visibilidad_media_sm', 'prop_lluvia', 'prop_ifr_aprox']
labels_box     = ['Temp. media (°C)', 'Humedad (%)', 'Viento (kt)',
                  'Visibilidad (sm)', 'Prop. lluvia', 'Prop. IFR']

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
for ax, col, label in zip(axes.flatten(), vars_meteo_box, labels_box):
    data_by_c = [df[df[TARGET_COL] == c][col].dropna().values for c in TARGET_ORDER]
    bp = ax.boxplot(data_by_c, labels=TARGET_ORDER, patch_artist=True,
                    medianprops={'color': 'white', 'linewidth': 2}, showfliers=False)
    for patch, color in zip(bp['boxes'], [PALETTE_TARGET[c] for c in TARGET_ORDER]):
        patch.set_facecolor(color)
        patch.set_alpha(0.8)
    # Añadir medias como puntos
    for i, (c, vals) in enumerate(zip(TARGET_ORDER, data_by_c)):
        if len(vals) > 0:
            ax.scatter(i+1, np.mean(vals), marker='D', color='white',
                       edgecolors='black', zorder=5, s=40)
    ax.set_title(label, fontweight='bold', fontsize=10)
    ax.set_xlabel('Nivel target')

plt.suptitle('Variables meteorológicas por clase del target\n(caja=Q1-Q3, ◇=media, línea blanca=mediana)',
             fontweight='bold', fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###  6.4 Fenómenos meteorológicos adversos

# %%
vars_fenomenos = ['prop_lluvia', 'prop_tormenta', 'prop_niebla',
                  'prop_baja_visibilidad', 'prop_viento_fuerte',
                  'prop_rafaga', 'prop_ifr_aprox']
labels_fen = {
    'prop_lluvia':           'Lluvia',
    'prop_tormenta':         'Tormenta',
    'prop_niebla':           'Niebla',
    'prop_baja_visibilidad': 'Baja visibilidad',
    'prop_viento_fuerte':    'Viento fuerte',
    'prop_rafaga':           'Ráfaga',
    'prop_ifr_aprox':        'IFR (aprox.)',
}

# Medias generales
medias_fen = df[vars_fenomenos].mean().rename(labels_fen).sort_values(ascending=True)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

bars = axes[0].barh(medias_fen.index, medias_fen.values, color='#D65F5F', edgecolor='white')
for bar, val in zip(bars, medias_fen.values):
    axes[0].text(val + 0.001, bar.get_y() + bar.get_height()/2,
                f'{val:.3f}', va='center', fontsize=9)
axes[0].set_title('Proporción media de fenómenos adversos\n(todos los aeropuertos con METAR)',
                  fontweight='bold')
axes[0].set_xlabel('Proporción media mensual')

# Por clase del target
fen_by_target = {}
for col in vars_fenomenos:
    fen_by_target[labels_fen[col]] = {
        nivel: df[df[TARGET_COL] == nivel][col].mean()
        for nivel in TARGET_ORDER
    }
df_fen = pd.DataFrame(fen_by_target).T

x = np.arange(len(df_fen))
w = 0.25
for i, nivel in enumerate(TARGET_ORDER):
    axes[1].bar(x + i*w, df_fen[nivel], width=w, label=nivel,
               color=PALETTE_TARGET[nivel], edgecolor='white')
axes[1].set_xticks(x + w)
axes[1].set_xticklabels(df_fen.index, rotation=30, ha='right', fontsize=9)
axes[1].set_title('Fenómenos adversos por clase del target', fontweight='bold')
axes[1].set_ylabel('Proporción media mensual')
axes[1].legend(title='Nivel')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. EDA geográfico del dataset mensual aeroportuario

# %%
df_geo_gold = spark.read.parquet(str(GOLD_MONTHLY_DIR / "monthly_airport_model_dataset.parquet"))

print("Filas:", df_geo_gold.count())
print("Columnas:", len(df_geo_gold.columns))

display(df_geo_gold.limit(5))
# Out:
# Filas: 3254
# Columnas: 66
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>icao_code</th><th>fecha_mes</th><th>operaciones_llegada</th><th>operaciones_salida</th><th>TOQUE Y DESPEGUE</th><th>operaciones_otras</th><th>operaciones_total</th><th>pasajeros_salida</th><th>carga_salida_kg</th><th>n_destinos_total</th><th>n_empresas_salida</th><th>n_registros_salida</th><th>pasajeros_llegada</th><th>carga_llegada_kg</th><th>n_origenes_total</th><th>n_empresas_llegada</th><th>n_registros_llegada</th><th>pasajeros_total</th><th>carga_total_kg</th><th>pasajeros_salida_internacional</th><th>pasajeros_salida_nacional</th><th>pasajeros_llegada_internacional</th><th>pasajeros_llegada_nacional</th><th>pasajeros_internacional_total</th><th>proporcion_pasajeros_internacional</th><th>n_metar_mes</th><th>temp_media_c</th><th>temp_min_c</th><th>temp_max_c</th><th>temp_std_c</th><th>dewpoint_media_c</th><th>humedad_media_pct</th><th>viento_medio_kt</th><th>viento_max_kt</th><th>viento_std_kt</th><th>rafaga_max_kt</th><th>visibilidad_media_sm</th><th>visibilidad_min_sm</th><th>visibilidad_std_sm</th><th>cloud_base_min_ft</th><th>altimeter_media_inhg</th><th>prop_lluvia</th><th>prop_tormenta</th><th>prop_niebla</th><th>prop_baja_visibilidad</th><th>prop_viento_fuerte</th><th>prop_rafaga</th><th>prop_ifr_aprox</th><th>n_metar_esperados_mes</th><th>cobertura_metar_ratio</th><th>name</th><th>type</th><th>municipality</th><th>region_name</th><th>iata_code</th><th>latitude_deg</th><th>longitude_deg</th><th>elevation_ft</th><th>scheduled_service</th><th>tiene_metar_mes</th><th>tiene_od_mes</th><th>sin_od_sin_metar_mes</th><th>target_operaciones_total_mes_siguiente</th><th>target_q33_operaciones</th><th>target_q66_operaciones</th><th>target_nivel_operacion_mes_siguiente</th></tr></thead><tbody><tr><td>SKAR</td><td>2020-01-01</td><td>408.0</td><td>409.0</td><td>0.0</td><td>0.0</td><td>817.0</td><td>25548.0</td><td>119.0</td><td>73</td><td>5</td><td>85</td><td>22854.0</td><td>0.0</td><td>71</td><td>5</td><td>85</td><td>48402.0</td><td>119.0</td><td>4448.0</td><td>21100.0</td><td>3880.0</td><td>18974.0</td><td>8328.0</td><td>0.17205900582620554</td><td>573</td><td>23.653846153846153</td><td>15.0</td><td>33.00000000000001</td><td>4.334010316828683</td><td>18.793706293706293</td><td>76.9764335664337</td><td>1.2</td><td>12.0</td><td>1.983765392331008</td><td>null</td><td>5.809544658493886</td><td>0.62</td><td>1.0573798149208828</td><td>600.0</td><td>30.03521815008726</td><td>0.1082024432809773</td><td>0.012216404886561954</td><td>0.0506108202443281</td><td>0.047285464098073555</td><td>0.0</td><td>0.0</td><td>0.04903677758318739</td><td>744</td><td>0.7701612903225806</td><td>El Eden Airport</td><td>medium_airport</td><td>Armenia</td><td>Quindio Department</td><td>AXM</td><td>4.45278</td><td>-75.7664</td><td>3990</td><td>1</td><td>1</td><td>1</td><td>0</td><td>744.0</td><td>220.0</td><td>564.0</td><td>alto</td></tr><tr><td>SKAR</td><td>2020-02-01</td><td>372.0</td><td>372.0</td><td>0.0</td><td>0.0</td><td>744.0</td><td>22490.0</td><td>182.0</td><td>66</td><td>6</td><td>76</td><td>22022.0</td><td>130.0</td><td>71</td><td>6</td><td>82</td><td>44512.0</td><td>312.0</td><td>3206.0</td><td>19284.0</td><td>2930.0</td><td>19092.0</td><td>6136.0</td><td>0.1378504672897196</td><td>508</td><td>23.823762376237624</td><td>16.0</td><td>34.0</td><td>4.35555539518966</td><td>18.883168316831682</td><td>76.7702772277228</td><td>1.2693069306930693</td><td>13.0</td><td>2.053536562987683</td><td>null</td><td>5.627658730158736</td><td>0.19</td><td>1.3089271685649784</td><td>300.0</td><td>30.02348425196852</td><td>0.13385826771653545</td><td>0.025590551181102362</td><td>0.09645669291338582</td><td>0.06349206349206349</td><td>0.0</td><td>0.0</td><td>0.06746031746031746</td><td>696</td><td>0.7298850574712644</td><td>El Eden Airport</td><td>medium_airport</td><td>Armenia</td><td>Quindio Department</td><td>AXM</td><td>4.45278</td><td>-75.7664</td ...

# %% [markdown]
# ### 7.1. Generación dataset para gráficas geograficas

# %%
df_airports_geo = (
    df_geo_gold
    .select(
        "icao_code",
        "iata_code",
        "name",
        "type",
        "municipality",
        "region_name",
        F.col("latitude_deg").cast("double").alias("latitude_deg"),
        F.col("longitude_deg").cast("double").alias("longitude_deg"),
        F.col("elevation_ft").cast("double").alias("elevation_ft"),
        "scheduled_service",
    )
    .filter(F.col("latitude_deg").isNotNull())
    .filter(F.col("longitude_deg").isNotNull())
    .dropDuplicates(["icao_code"])
)

print("Aeropuertos con coordenadas:", df_airports_geo.count())

display(df_airports_geo)
# Out:
# Aeropuertos con coordenadas: 46
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>icao_code</th><th>iata_code</th><th>name</th><th>type</th><th>municipality</th><th>region_name</th><th>latitude_deg</th><th>longitude_deg</th><th>elevation_ft</th><th>scheduled_service</th></tr></thead><tbody><tr><td>SKAR</td><td>AXM</td><td>El Eden Airport</td><td>medium_airport</td><td>Armenia</td><td>Quindio Department</td><td>4.45278</td><td>-75.7664</td><td>3990.0</td><td>1</td></tr><tr><td>SKAS</td><td>PUU</td><td>Tres De Mayo Airport</td><td>medium_airport</td><td>Puerto Asís</td><td>Putumayo Department</td><td>0.505228</td><td>-76.5008</td><td>815.0</td><td>1</td></tr><tr><td>SKBG</td><td>BGA</td><td>Palonegro Airport</td><td>medium_airport</td><td>Bucaramanga</td><td>Santander Department</td><td>7.1265</td><td>-73.1848</td><td>3897.0</td><td>1</td></tr><tr><td>SKBO</td><td>BOG</td><td>El Dorado International Airport</td><td>large_airport</td><td>Bogota</td><td>Bogotá Capital District</td><td>4.70159</td><td>-74.1469</td><td>8361.0</td><td>1</td></tr><tr><td>SKBQ</td><td>BAQ</td><td>Ernesto Cortissoz International Airport</td><td>large_airport</td><td>Barranquilla</td><td>Atlántico Department</td><td>10.8896</td><td>-74.7808</td><td>98.0</td><td>1</td></tr><tr><td>SKBS</td><td>BSC</td><td>José Celestino Mutis Airport</td><td>medium_airport</td><td>Bahía Solano</td><td>Chocó Department</td><td>6.20292</td><td>-77.3947</td><td>80.0</td><td>1</td></tr><tr><td>SKBU</td><td>BUN</td><td>Gerardo Tobar López Airport</td><td>medium_airport</td><td>Buenaventura</td><td>Valle del Cauca Department</td><td>3.81963</td><td>-76.9898</td><td>48.0</td><td>1</td></tr><tr><td>SKCC</td><td>CUC</td><td>Camilo Daza International Airport</td><td>medium_airport</td><td>Cúcuta</td><td>Norte de Santander Department</td><td>7.92757</td><td>-72.5115</td><td>1096.0</td><td>1</td></tr><tr><td>SKCG</td><td>CTG</td><td>Rafael Nuñez International Airport</td><td>large_airport</td><td>Cartagena</td><td>Bolívar Department</td><td>10.4424</td><td>-75.513</td><td>4.0</td><td>1</td></tr><tr><td>SKCL</td><td>CLO</td><td>Alfonso Bonilla Aragon International Airport</td><td>large_airport</td><td>Cali</td><td>Valle del Cauca Department</td><td>3.542717</td><td>-76.381898</td><td>3162.0</td><td>1</td></tr><tr><td>SKCO</td><td>TCO</td><td>La Florida Airport</td><td>medium_airport</td><td>Tumaco</td><td>Nariño Department</td><td>1.81442</td><td>-78.7492</td><td>8.0</td><td>1</td></tr><tr><td>SKCZ</td><td>CZU</td><td>Las Brujas Airport</td><td>medium_airport</td><td>Corozal</td><td>Sucre Department</td><td>9.33274</td><td>-75.2856</td><td>528.0</td><td>1</td></tr><tr><td>SKEJ</td><td>EJA</td><td>Yariguíes Airport</td><td>medium_airport</td><td>Barrancabermeja</td><td>Santander Department</td><td>7.02433</td><td>-73.8068</td><td>412.0</td><td>1</td></tr><tr><td>SKFL</td><td>FLA</td><td>Gustavo Artunduaga Paredes Airport</td><td>medium_airport</td><td>Florencia</td><td>Caquetá Department</td><td>1.58919</td><td>-75.5644</td><td>803.0</td><td>1</td></tr><tr><td>SKGI</td><td>GIR</td><td>Santiago Vila Airport</td><td>medium_airport</td><td>Girardot</td><td>Cundinamarca Department</td><td>4.27624</td><td>-74.7967</td><td>900.0</td><td>0</td></tr><tr><td>SKGO</td><td>CRC</td><td>Santa Ana Airport</td><td>medium_airport</td><td>Cartago</td><td>Valle del Cauca Department</td><td>4.75818</td><td>-75.9557</td><td>2979.0</td><td>0</td></tr><tr><td>SKGP</td><td>GPI</td><td>Guapi Airport</td><td>medium_airport</td><td>Guapi</td><td>Cauca Department</td><td>2.57013</td><td>-77.897969</td><td>164.0</td><td>1</td></tr><tr><td>SKGY</td><td></td><td>Guaymaral Airport</td><td>small_airport</td><td>Chía</td><td>Bogotá Capital District</td><td>4.81233</td><td>-74.0649</td><td>8390.0</td><td>0</td></tr><tr><td>SKIB</td><td>IBE</td><td>Perales Airport</td><td>medium_airport</td><td>Ibagué</td><td>Tolima Department</td><td>4.42161</td><td>-75.1333</td><td>2999.0</td><td>1 ...

# %% [markdown]
# ### 7.2. Preparar columnas geográficas

# %%
df_geo_base = (
    df_geo_gold
    .withColumn(
        "latitude_deg_num",
        F.regexp_replace(F.col("latitude_deg").cast("string"), ",", ".").cast("double"),
    )
    .withColumn(
        "longitude_deg_num",
        F.regexp_replace(F.col("longitude_deg").cast("string"), ",", ".").cast("double"),
    )
    .withColumn(
        "elevation_ft_num",
        F.regexp_replace(F.col("elevation_ft").cast("string"), ",", ".").cast("double"),
    )
    .filter(F.col("latitude_deg_num").isNotNull())
    .filter(F.col("longitude_deg_num").isNotNull())
)

print("Filas con coordenadas válidas:", df_geo_base.count())

display(
    df_geo_base
    .select(
        "icao_code",
        "name",
        "municipality",
        "region_name",
        "type",
        "latitude_deg_num",
        "longitude_deg_num",
        "elevation_ft_num",
    )
    .dropDuplicates(["icao_code"])
    .orderBy("icao_code")
)
# Out:
# Filas con coordenadas válidas: 3254
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>icao_code</th><th>name</th><th>municipality</th><th>region_name</th><th>type</th><th>latitude_deg_num</th><th>longitude_deg_num</th><th>elevation_ft_num</th></tr></thead><tbody><tr><td>SKAR</td><td>El Eden Airport</td><td>Armenia</td><td>Quindio Department</td><td>medium_airport</td><td>4.45278</td><td>-75.7664</td><td>3990.0</td></tr><tr><td>SKAS</td><td>Tres De Mayo Airport</td><td>Puerto Asís</td><td>Putumayo Department</td><td>medium_airport</td><td>0.505228</td><td>-76.5008</td><td>815.0</td></tr><tr><td>SKBG</td><td>Palonegro Airport</td><td>Bucaramanga</td><td>Santander Department</td><td>medium_airport</td><td>7.1265</td><td>-73.1848</td><td>3897.0</td></tr><tr><td>SKBO</td><td>El Dorado International Airport</td><td>Bogota</td><td>Bogotá Capital District</td><td>large_airport</td><td>4.70159</td><td>-74.1469</td><td>8361.0</td></tr><tr><td>SKBQ</td><td>Ernesto Cortissoz International Airport</td><td>Barranquilla</td><td>Atlántico Department</td><td>large_airport</td><td>10.8896</td><td>-74.7808</td><td>98.0</td></tr><tr><td>SKBS</td><td>José Celestino Mutis Airport</td><td>Bahía Solano</td><td>Chocó Department</td><td>medium_airport</td><td>6.20292</td><td>-77.3947</td><td>80.0</td></tr><tr><td>SKBU</td><td>Gerardo Tobar López Airport</td><td>Buenaventura</td><td>Valle del Cauca Department</td><td>medium_airport</td><td>3.81963</td><td>-76.9898</td><td>48.0</td></tr><tr><td>SKCC</td><td>Camilo Daza International Airport</td><td>Cúcuta</td><td>Norte de Santander Department</td><td>medium_airport</td><td>7.92757</td><td>-72.5115</td><td>1096.0</td></tr><tr><td>SKCG</td><td>Rafael Nuñez International Airport</td><td>Cartagena</td><td>Bolívar Department</td><td>large_airport</td><td>10.4424</td><td>-75.513</td><td>4.0</td></tr><tr><td>SKCL</td><td>Alfonso Bonilla Aragon International Airport</td><td>Cali</td><td>Valle del Cauca Department</td><td>large_airport</td><td>3.542717</td><td>-76.381898</td><td>3162.0</td></tr><tr><td>SKCO</td><td>La Florida Airport</td><td>Tumaco</td><td>Nariño Department</td><td>medium_airport</td><td>1.81442</td><td>-78.7492</td><td>8.0</td></tr><tr><td>SKCZ</td><td>Las Brujas Airport</td><td>Corozal</td><td>Sucre Department</td><td>medium_airport</td><td>9.33274</td><td>-75.2856</td><td>528.0</td></tr><tr><td>SKEJ</td><td>Yariguíes Airport</td><td>Barrancabermeja</td><td>Santander Department</td><td>medium_airport</td><td>7.02433</td><td>-73.8068</td><td>412.0</td></tr><tr><td>SKFL</td><td>Gustavo Artunduaga Paredes Airport</td><td>Florencia</td><td>Caquetá Department</td><td>medium_airport</td><td>1.58919</td><td>-75.5644</td><td>803.0</td></tr><tr><td>SKGI</td><td>Santiago Vila Airport</td><td>Girardot</td><td>Cundinamarca Department</td><td>medium_airport</td><td>4.27624</td><td>-74.7967</td><td>900.0</td></tr><tr><td>SKGO</td><td>Santa Ana Airport</td><td>Cartago</td><td>Valle del Cauca Department</td><td>medium_airport</td><td>4.75818</td><td>-75.9557</td><td>2979.0</td></tr><tr><td>SKGP</td><td>Guapi Airport</td><td>Guapi</td><td>Cauca Department</td><td>medium_airport</td><td>2.57013</td><td>-77.897969</td><td>164.0</td></tr><tr><td>SKGY</td><td>Guaymaral Airport</td><td>Chía</td><td>Bogotá Capital District</td><td>small_airport</td><td>4.81233</td><td>-74.0649</td><td>8390.0</td></tr><tr><td>SKIB</td><td>Perales Airport</td><td>Ibagué</td><td>Tolima Department</td><td>medium_airport</td><td>4.42161</td><td>-75.1333</td><td>2999.0</td></tr><tr><td>SKIP</td><td>San Luis Airport</td><td>Ipiales</td><td>Nariño Department</td><td>medium_airport</td><td>0.861946</td><td>-77.671783</td><td>9765.0</td></tr><tr><td>SKLC</td><td>Antonio Roldán Betancur Airport</td><td>Carepa</td><td>Antioquía Department</td><td>medium_airport</td><td>7.81196</td><td>-76.7164</td><td>46.0</td></tr><tr><td>SKLT</td><td>Alfredo Vásquez Cobo International Airport</td><td>Leticia</td><td>Amazonas De ...

# %% [markdown]
# ### 7.3. Construir dataset geográfico agregado por aeropuerto

# %%
cols_meteo_adverso = [
    "prop_lluvia",
    "prop_tormenta",
    "prop_niebla",
    "prop_baja_visibilidad",
    "prop_viento_fuerte",
    "prop_rafaga",
    "prop_ifr_aprox",
]

cols_meteo_adverso_existentes = [
    col_name
    for col_name in cols_meteo_adverso
    if col_name in df_geo_base.columns
]

if "meteo_adverso_score" not in df_geo_base.columns:

    if len(cols_meteo_adverso_existentes) > 0:

        suma_componentes = None

        for col_name in cols_meteo_adverso_existentes:

            componente = F.coalesce(
                F.col(col_name).cast("double"),
                F.lit(0.0),
            )

            if suma_componentes is None:
                suma_componentes = componente
            else:
                suma_componentes = suma_componentes + componente

        df_geo_base = df_geo_base.withColumn(
            "meteo_adverso_score",
            suma_componentes / F.lit(len(cols_meteo_adverso_existentes)),
        )

        print(
            "[OK] Se creó meteo_adverso_score usando:",
            cols_meteo_adverso_existentes,
        )

    else:
        df_geo_base = df_geo_base.withColumn(
            "meteo_adverso_score",
            F.lit(None).cast("double"),
        )

        print(
            "[WARN] No se encontraron columnas meteorológicas adversas "
            "para crear meteo_adverso_score."
        )


agregaciones_geo = [
    F.count("*").alias("n_meses"),
    F.sum("operaciones_total").alias("operaciones_total_acum"),
    F.avg("operaciones_total").alias("operaciones_total_prom_mes"),
    F.sum("pasajeros_total").alias("pasajeros_total_acum"),
    F.avg("pasajeros_total").alias("pasajeros_total_prom_mes"),
]

if "cobertura_metar_ratio" in df_geo_base.columns:
    agregaciones_geo.append(
        F.avg("cobertura_metar_ratio").alias("cobertura_metar_prom")
    )

if "n_metar_mes" in df_geo_base.columns:
    agregaciones_geo.append(
        F.sum("n_metar_mes").alias("n_metar_total")
    )

if "meteo_adverso_score" in df_geo_base.columns:
    agregaciones_geo.append(
        F.avg("meteo_adverso_score").alias("meteo_adverso_prom")
    )

if "temp_media_c" in df_geo_base.columns:
    agregaciones_geo.append(
        F.avg("temp_media_c").alias("temp_media_prom_c")
    )

if "viento_medio_kt" in df_geo_base.columns:
    agregaciones_geo.append(
        F.avg("viento_medio_kt").alias("viento_medio_prom_kt")
    )

if "visibilidad_media_sm" in df_geo_base.columns:
    agregaciones_geo.append(
        F.avg("visibilidad_media_sm").alias("visibilidad_media_prom_sm")
    )


df_airport_geo_agg = (
    df_geo_base
    .groupBy(
        "icao_code",
        "name",
        "type",
        "municipality",
        "region_name",
        "iata_code",
        "scheduled_service",
        "latitude_deg_num",
        "longitude_deg_num",
        "elevation_ft_num",
    )
    .agg(*agregaciones_geo)
)

display(
    df_airport_geo_agg
    .orderBy(F.desc("operaciones_total_acum"))
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>icao_code</th><th>name</th><th>type</th><th>municipality</th><th>region_name</th><th>iata_code</th><th>scheduled_service</th><th>latitude_deg_num</th><th>longitude_deg_num</th><th>elevation_ft_num</th><th>n_meses</th><th>operaciones_total_acum</th><th>operaciones_total_prom_mes</th><th>pasajeros_total_acum</th><th>pasajeros_total_prom_mes</th><th>cobertura_metar_prom</th><th>n_metar_total</th><th>meteo_adverso_prom</th><th>temp_media_prom_c</th><th>viento_medio_prom_kt</th><th>visibilidad_media_prom_sm</th></tr></thead><tbody><tr><td>SKBO</td><td>El Dorado International Airport</td><td>large_airport</td><td>Bogota</td><td>Bogotá Capital District</td><td>BOG</td><td>1</td><td>4.70159</td><td>-74.1469</td><td>8361.0</td><td>71</td><td>1744239.0</td><td>24566.74647887324</td><td>1.6547643E8</td><td>2330653.943661972</td><td>1.0881674470876672</td><td>56437</td><td>0.05241241373693235</td><td>14.077529023199535</td><td>5.075974035603335</td><td>5.934724246158952</td></tr><tr><td>SKRG</td><td>Jose Maria Córdova International Airport</td><td>large_airport</td><td>Medellín</td><td>Antioquía Department</td><td>MDE</td><td>1</td><td>6.16454</td><td>-75.4231</td><td>6955.0</td><td>71</td><td>493651.0</td><td>6952.830985915493</td><td>5.7960717E7</td><td>816348.1267605633</td><td>1.0456834474900323</td><td>54231</td><td>0.11026976210703529</td><td>16.85756731805553</td><td>4.153458172151958</td><td>5.415566360999653</td></tr><tr><td>SKCL</td><td>Alfonso Bonilla Aragon International Airport</td><td>large_airport</td><td>Cali</td><td>Valle del Cauca Department</td><td>CLO</td><td>1</td><td>3.542717</td><td>-76.381898</td><td>3162.0</td><td>71</td><td>306941.0</td><td>4323.112676056338</td><td>3.2231271E7</td><td>453961.5633802817</td><td>1.0587503702228196</td><td>54908</td><td>0.051557875849633984</td><td>23.668026624603584</td><td>4.5787983853328145</td><td>5.7374991412208605</td></tr><tr><td>SKCG</td><td>Rafael Nuñez International Airport</td><td>large_airport</td><td>Cartagena</td><td>Bolívar Department</td><td>CTG</td><td>1</td><td>10.4424</td><td>-75.513</td><td>4.0</td><td>71</td><td>253661.0</td><td>3572.6901408450703</td><td>3.2688287E7</td><td>460398.40845070424</td><td>0.9774874481719142</td><td>50685</td><td>0.01763812927299456</td><td>28.44026973196675</td><td>6.156424919421658</td><td>6.128789864068513</td></tr><tr><td>SKMD</td><td>Enrique Olaya Herrera Airport</td><td>medium_airport</td><td>Medellín</td><td>Antioquía Department</td><td>EOH</td><td>1</td><td>6.219686</td><td>-75.590597</td><td>4949.0</td><td>71</td><td>181879.0</td><td>2561.676056338028</td><td>6606734.0</td><td>93052.59154929577</td><td>0.4756854739552908</td><td>23974</td><td>0.05074995682062971</td><td>23.464979773967485</td><td>5.804461168560966</td><td>6.033082996434448</td></tr><tr><td>SKBQ</td><td>Ernesto Cortissoz International Airport</td><td>large_airport</td><td>Barranquilla</td><td>Atlántico Department</td><td>BAQ</td><td>1</td><td>10.8896</td><td>-74.7808</td><td>98.0</td><td>71</td><td>165595.0</td><td>2332.323943661972</td><td>1.5059954E7</td><td>212112.02816901408</td><td>1.0343663560276504</td><td>53646</td><td>0.04312038361398876</td><td>27.909855418319417</td><td>6.628398072670833</td><td>5.906370372730164</td></tr><tr><td>SKBG</td><td>Palonegro Airport</td><td>medium_airport</td><td>Bucaramanga</td><td>Santander Department</td><td>BGA</td><td>1</td><td>7.1265</td><td>-73.1848</td><td>3897.0</td><td>71</td><td>141342.0</td><td>1990.7323943661972</td><td>9737843.0</td><td>137152.71830985916</td><td>0.7977210003314907</td><td>41372</td><td>0.05021458285760817</td><td>22.537703016476225</td><td>4.391734867058646</td><td>5.810880224163558</td></tr><tr><td>SKQU</td><td>Mariquita Airport</td><td>medium_airport</td><td>Mariquita</td><td>Tolima Department</td><td>MQU</td><td>0</td><td>5.21256</td><td>-74.8836</td><td>1531.0</td><td ...

# %% [markdown]
# ### 7.4. Función auxiliar para mapas Plotly

# %%
def mostrar_mapa_plotly(
    df_pd,
    lat_col,
    lon_col,
    title,
    color_col=None,
    size_col=None,
    hover_name_col="name",
    hover_data=None,
    zoom=4.7,
    height=720,
    center_lat=4.5709,
    center_lon=-74.2973,
    map_style="open-street-map",
    marker_size=10,
    size_max=18,
    opacity=0.80,
    color_discrete_map=None,
    color_continuous_scale="Viridis",
    ordenar_por_size=True,
    ascending_size=False,
):
    """
    Crea mapa interactivo con Plotly.

    Esta versión mantiene compatibilidad con parámetros usados antes:
    - center_lat
    - center_lon
    - map_style
    - marker_size
    - size_max
    - opacity
    - color_discrete_map
    - color_continuous_scale

    También permite ordenar por tamaño para mejorar visibilidad.
    """

    df_plot = df_pd.copy()

    # Asegurar coordenadas numéricas
    df_plot[lat_col] = pd.to_numeric(
        df_plot[lat_col],
        errors="coerce",
    )

    df_plot[lon_col] = pd.to_numeric(
        df_plot[lon_col],
        errors="coerce",
    )

    df_plot = df_plot.dropna(
        subset=[
            lat_col,
            lon_col,
        ]
    )

    # Preparar tamaño si existe size_col
    if size_col is not None and size_col in df_plot.columns:
        df_plot[size_col] = pd.to_numeric(
            df_plot[size_col],
            errors="coerce",
        ).fillna(0)

        if ordenar_por_size:
            df_plot = df_plot.sort_values(
                by=size_col,
                ascending=ascending_size,
            )

    center = {
        "lat": center_lat,
        "lon": center_lon,
    }

    common_args = dict(
        data_frame=df_plot,
        lat=lat_col,
        lon=lon_col,
        color=color_col,
        size=size_col,
        hover_name=hover_name_col,
        hover_data=hover_data,
        zoom=zoom,
        center=center,
        height=height,
        title=title,
        size_max=size_max,
        color_discrete_map=color_discrete_map,
        color_continuous_scale=color_continuous_scale,
    )

    # Usar px.scatter_map si está disponible
    if hasattr(px, "scatter_map"):

        fig = px.scatter_map(**common_args)

        fig.update_layout(
            map_style=map_style,
            template="plotly_white",
            paper_bgcolor="white",
            plot_bgcolor="white",
            margin={
                "r": 10,
                "t": 60,
                "l": 10,
                "b": 10,
            },
            title={
                "x": 0.5,
                "xanchor": "center",
                "font": {
                    "size": 20,
                },
            },
            legend=dict(
                title=color_col if color_col else "",
                bgcolor="rgba(255,255,255,0.90)",
                bordercolor="rgba(0,0,0,0.25)",
                borderwidth=1,
            ),
        )

    # Fallback: px.scatter_mapbox
    else:

        fig = px.scatter_mapbox(**common_args)

        fig.update_layout(
            mapbox_style=map_style,
            template="plotly_white",
            paper_bgcolor="white",
            plot_bgcolor="white",
            margin={
                "r": 10,
                "t": 60,
                "l": 10,
                "b": 10,
            },
            title={
                "x": 0.5,
                "xanchor": "center",
                "font": {
                    "size": 20,
                },
            },
            legend=dict(
                title=color_col if color_col else "",
                bgcolor="rgba(255,255,255,0.90)",
                bordercolor="rgba(0,0,0,0.25)",
                borderwidth=1,
            ),
        )

    # Mejorar visibilidad de puntos
    if size_col is None:
        fig.update_traces(
            marker=dict(
                size=marker_size,
                opacity=opacity,
            )
        )
    else:
        fig.update_traces(
            marker=dict(
                opacity=opacity,
            )
        )

    fig.show()

    return fig

# %% [markdown]
# ### 7.5. Mapa 1: distribución geográfica de aeropuertos

# %%
airport_geo_pd = df_airport_geo_agg.toPandas()

color_map_airport_type = {
    "large_airport": "#E63946",    # rojo fuerte
    "medium_airport": "#F77F00",   # naranja fuerte
    "small_airport": "#0077B6",    # azul fuerte
}

fig_geo = mostrar_mapa_plotly(
    df_pd=airport_geo_pd,
    lat_col="latitude_deg_num",
    lon_col="longitude_deg_num",
    title="Distribución geográfica de aeropuertos en el dataset",
    color_col="type",
    size_col=None,
    hover_name_col="name",
    hover_data=[
        "icao_code",
        "municipality",
        "region_name",
        "operaciones_total_acum",
        "pasajeros_total_acum",
    ],
    zoom=5.0,
    height=760,
    center_lat=4.5709,
    center_lon=-74.2973,
    map_style="carto-positron",
    marker_size=15,
    opacity=0.98,
    color_discrete_map=color_map_airport_type,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="6d1d6aec-b809-44aa-9c81-2dc771e0f600" class="plotly-graph-div" style="height:760px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d1d6aec-b809-44aa-9c81-2dc771e0f600")) {                    Plotly.newPlot(                        "6d1d6aec-b809-44aa-9c81-2dc771e0f600",                        [{"customdata":[["SKPS","Chachag\u00fc\u00ed","Nari\u00f1o Department",37047.0,3317573.0],["SKBG","Bucaramanga","Santander Department",141342.0,9737843.0],["SKGO","Cartago","Valle del Cauca Department",631.0,0.0],["SKMR","Monter\u00eda","C\u00f3rdoba Department",71406.0,6900839.0],["SKVP","Valledupar","C\u00e9sar Department",23482.0,2164016.0],["SKAS","Puerto As\u00eds","Putumayo Department",18893.0,617128.0],["SKCC","C\u00facuta","Norte de Santander Department",91632.0,7292205.0],["SKCZ","Corozal","Sucre Department",8799.0,251722.0],["SKGI","Girardot","Cundinamarca Department",23495.0,5021.0],["SKRH","Riohacha","La Guajira Department",20663.0,2375240.0],["SKPE","Pereira","Risaralda Department",108262.0,11681624.0],["SKLT","Leticia","Amazonas Department",25128.0,1662871.0],["SKUI","Quibd\u00f3","Choc\u00f3 Department",52634.0,1826104.0],["SKPD","Puerto In\u00edrida","Guain\u00eda Department",12491.0,0.0],["SKVV","Villavicencio","Meta Department",32389.0,1338882.0],["SKBU","Buenaventura","Valle del Cauca Department",4734.0,46277.0],["SKMZ","Manizales","Caldas Department",15568.0,571346.0],["SKSJ","San Jos\u00e9 Del Guaviare","Guaviare Department",26177.0,212122.0],["SKSM","Santa Marta","Magdalena Department",121907.0,16818305.0],["SKYP","Yopal","Casanare Department",68194.0,1501989.0],["SKCO","Tumaco","Nari\u00f1o Department",38262.0,744364.0],["SKBS","Bah\u00eda Solano","Choc\u00f3 Department",9088.0,465996.0],["SKIB","Ibagu\u00e9","Tolima Department",39617.0,862852.0],["SKNV","Neiva","Huila Department",60395.0,1666177.0],["SKPC","Puerto Carre\u00f1o","Vichada Department",11136.0,326161.0],["SKTM","Tame","Arauca Department",16145.0,47656.0],["SKFL","Florencia","Caquet\u00e1 Department",21731.0,575184.0],["SKIP","Ipiales","Nari\u00f1o Department",6742.0,444506.0],["SKPP","Popay\u00e1n","Cauca Department",31045.0,684619.0],["SKQU","Mariquita","Tolima Department",134185.0,611.0],["SKAR","Armenia","Quindio Department",32737.0,3067224.0],["SKUC","Arauca","Arauca Department",41211.0,807483.0],["SKEJ","Barrancabermeja","Santander Department",48934.0,622877.0],["SKGP","Guapi","Cauca Department",12147.0,357042.0],["SKMU","Mit\u00fa","Vaup\u00e9s Department",8202.0,279597.0],["SKLC","Carepa","Antioqu\u00eda Department",38499.0,1133326.0],["SKMD","Medell\u00edn","Antioqu\u00eda Department",181879.0,6606734.0],["SKPV","Providencia","San Andr\u00e9s, Providencia y Santa Catalina Department",13944.0,352891.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>type=medium_airport<br>latitude_deg_num=%{lat}<br>longitude_deg_num=%{lon}<br>icao_code=%{customdata[0]}<br>municipality=%{customdata[1]}<br>region_name=%{customdata[2]}<br>operaciones_total_acum=%{customdata[3]}<br>pasajeros_total_acum=%{customdata[4]}<extra></extra>","hovertext":["Antonio Nari\u00f1o Airport","Palonegro Airport","Santa Ana Airport","Los Garzones Airport","Alfonso L\u00f3pez Pumarejo Airport","Tres De Mayo Airport","Camilo Daza International Airport","Las Brujas Airport","Santiago Vila Airport","Almirante Padilla Airport","Mateca\u00f1a International Airport","Alfredo V\u00e1squez Cobo International Airport","El Cara\u00f1o Airport","Obando Cesar Gaviria Trujillo Airport","Vanguardia Airport","Gerardo Tobar L\u00f3pez Airport","La Nubia Airport","Jorge E. Gonzalez Torres Airport","Sim\u00f3n Bol\u00edvar International Airport","El Alcaravan - Yopal Airport","La Florida Airport","Jos\u00e9 Celestino Mutis Airport","Perales Airport","Benit ...

# %% [markdown]
# ### 7.6. Mapa 2: concentración de operaciones por aeropuerto

# %%
airport_geo_pd = df_airport_geo_agg.toPandas()

airport_geo_pd["operaciones_total_acum_plot"] = np.log1p(
    airport_geo_pd["operaciones_total_acum"]
)

airport_geo_pd["operaciones_total_acum_color"] = np.log1p(
    airport_geo_pd["operaciones_total_acum"]
)

fig_operaciones = mostrar_mapa_plotly(
    df_pd=airport_geo_pd,
    lat_col="latitude_deg_num",
    lon_col="longitude_deg_num",
    title="Concentración geográfica de operaciones aeroportuarias",
    color_col="operaciones_total_acum_color",
    size_col="operaciones_total_acum_plot",
    hover_name_col="name",
    hover_data=[
        "icao_code",
        "municipality",
        "region_name",
        "type",
        "operaciones_total_acum",
        "operaciones_total_prom_mes",
        "pasajeros_total_acum",
        "n_meses",
    ],
    zoom=4.6,
    height=750,
    color_continuous_scale="Turbo",
    map_style="carto-positron",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="351682f0-4af7-4dac-9fc0-c2b352fbf3cd" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("351682f0-4af7-4dac-9fc0-c2b352fbf3cd")) {                    Plotly.newPlot(                        "351682f0-4af7-4dac-9fc0-c2b352fbf3cd",                        [{"customdata":[["SKBO","Bogota","Bogot\u00e1 Capital District","large_airport",1744239.0,24566.74647887324,165476430.0,71],["SKRG","Medell\u00edn","Antioqu\u00eda Department","large_airport",493651.0,6952.830985915493,57960717.0,71],["SKCL","Cali","Valle del Cauca Department","large_airport",306941.0,4323.112676056338,32231271.0,71],["SKCG","Cartagena","Bol\u00edvar Department","large_airport",253661.0,3572.6901408450703,32688287.0,71],["SKMD","Medell\u00edn","Antioqu\u00eda Department","medium_airport",181879.0,2561.676056338028,6606734.0,71],["SKBQ","Barranquilla","Atl\u00e1ntico Department","large_airport",165595.0,2332.323943661972,15059954.0,71],["SKBG","Bucaramanga","Santander Department","medium_airport",141342.0,1990.7323943661972,9737843.0,71],["SKQU","Mariquita","Tolima Department","medium_airport",134185.0,1889.9295774647887,611.0,71],["SKSM","Santa Marta","Magdalena Department","medium_airport",121907.0,1717.0,16818305.0,71],["SKPE","Pereira","Risaralda Department","medium_airport",108262.0,1524.8169014084508,11681624.0,71],["SKSP","San Andr\u00e9s","San Andr\u00e9s, Providencia y Santa Catalina Department","large_airport",103780.0,1461.6901408450703,12719085.0,71],["SKCC","C\u00facuta","Norte de Santander Department","medium_airport",91632.0,1290.5915492957747,7292205.0,71],["SKMR","Monter\u00eda","C\u00f3rdoba Department","medium_airport",71406.0,1005.7183098591549,6900839.0,71],["SKYP","Yopal","Casanare Department","medium_airport",68194.0,960.4788732394367,1501989.0,71],["SKNV","Neiva","Huila Department","medium_airport",60395.0,850.6338028169014,1666177.0,71],["SKGY","Ch\u00eda","Bogot\u00e1 Capital District","small_airport",52671.0,741.8450704225352,12589.0,71],["SKUI","Quibd\u00f3","Choc\u00f3 Department","medium_airport",52634.0,741.3239436619718,1826104.0,71],["SKEJ","Barrancabermeja","Santander Department","medium_airport",48934.0,689.2112676056338,622877.0,71],["SKUC","Arauca","Arauca Department","medium_airport",41211.0,580.4366197183099,807483.0,71],["SKIB","Ibagu\u00e9","Tolima Department","medium_airport",39617.0,557.9859154929577,862852.0,71],["SKLC","Carepa","Antioqu\u00eda Department","medium_airport",38499.0,542.2394366197183,1133326.0,71],["SKCO","Tumaco","Nari\u00f1o Department","medium_airport",38262.0,538.9014084507043,744364.0,71],["SKPS","Chachag\u00fc\u00ed","Nari\u00f1o Department","medium_airport",37047.0,521.7887323943662,3317573.0,71],["SKAR","Armenia","Quindio Department","medium_airport",32737.0,461.0845070422535,3067224.0,71],["SKVV","Villavicencio","Meta Department","medium_airport",32389.0,456.1830985915493,1338882.0,71],["SKPP","Popay\u00e1n","Cauca Department","medium_airport",31045.0,437.2535211267606,684619.0,71],["SKSA","Saravena","Arauca Department","small_airport",28087.0,395.59154929577466,227619.0,71],["SKSJ","San Jos\u00e9 Del Guaviare","Guaviare Department","medium_airport",26177.0,368.6901408450704,212122.0,71],["SKLT","Leticia","Amazonas Department","medium_airport",25128.0,353.9154929577465,1662871.0,71],["SKGI","Girardot","Cundinamarca Department","medium_airport",23495.0,361.46153846153845,5021.0,65],["SKVP","Valledupar","C\u00e9sar Department","medium_airport",23482.0,330.7323943661972,2164016.0,71],["SKFL","Florencia","Caquet\u00e1 Department","medium_airport",21731.0,306.07042253521126,575184.0,71],["SKRH","Riohacha","La Guajira Department","medium_airport",20663.0,291.0281690140845,2375240.0,71],["SKAS","Puerto As\u00eds"," ...

# %% [markdown]
# ### 7.7. Mapa 3: concentración de pasajeros por aeropuerto

# %%
# Tamaño de burbuja en escala logarítmica
airport_geo_pd["pasajeros_total_acum_plot"] = np.log1p(
    airport_geo_pd["pasajeros_total_acum"]
)

# Color también en escala logarítmica para mejorar contraste visual
airport_geo_pd["pasajeros_total_acum_color"] = np.log1p(
    airport_geo_pd["pasajeros_total_acum"]
)


fig_pasajeros = mostrar_mapa_plotly(
    df_pd=airport_geo_pd,
    lat_col="latitude_deg_num",
    lon_col="longitude_deg_num",
    title="Concentración geográfica de pasajeros por aeropuerto",
    color_col="pasajeros_total_acum",
    size_col="pasajeros_total_acum_plot",
    hover_name_col="name",
    hover_data=[
        "icao_code",
        "municipality",
        "region_name",
        "type",
        "pasajeros_total_acum",
        "pasajeros_total_prom_mes",
        "operaciones_total_acum",
        "operaciones_total_prom_mes",
        "n_meses",
    ],
    zoom=4.6,
    height=750,
    map_style="carto-positron",
    size_max=12,
    opacity=0.95,
    color_continuous_scale="Turbo",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="b2ca8784-c509-4e61-9acb-94c7cefdfbc5" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2ca8784-c509-4e61-9acb-94c7cefdfbc5")) {                    Plotly.newPlot(                        "b2ca8784-c509-4e61-9acb-94c7cefdfbc5",                        [{"customdata":[["SKBO","Bogota","Bogot\u00e1 Capital District","large_airport",165476430.0,2330653.943661972,1744239.0,24566.74647887324,71],["SKRG","Medell\u00edn","Antioqu\u00eda Department","large_airport",57960717.0,816348.1267605633,493651.0,6952.830985915493,71],["SKCG","Cartagena","Bol\u00edvar Department","large_airport",32688287.0,460398.40845070424,253661.0,3572.6901408450703,71],["SKCL","Cali","Valle del Cauca Department","large_airport",32231271.0,453961.5633802817,306941.0,4323.112676056338,71],["SKSM","Santa Marta","Magdalena Department","medium_airport",16818305.0,236877.53521126762,121907.0,1717.0,71],["SKBQ","Barranquilla","Atl\u00e1ntico Department","large_airport",15059954.0,212112.02816901408,165595.0,2332.323943661972,71],["SKSP","San Andr\u00e9s","San Andr\u00e9s, Providencia y Santa Catalina Department","large_airport",12719085.0,179142.04225352113,103780.0,1461.6901408450703,71],["SKPE","Pereira","Risaralda Department","medium_airport",11681624.0,164529.91549295775,108262.0,1524.8169014084508,71],["SKBG","Bucaramanga","Santander Department","medium_airport",9737843.0,137152.71830985916,141342.0,1990.7323943661972,71],["SKCC","C\u00facuta","Norte de Santander Department","medium_airport",7292205.0,102707.11267605633,91632.0,1290.5915492957747,71],["SKMR","Monter\u00eda","C\u00f3rdoba Department","medium_airport",6900839.0,97194.91549295775,71406.0,1005.7183098591549,71],["SKMD","Medell\u00edn","Antioqu\u00eda Department","medium_airport",6606734.0,93052.59154929577,181879.0,2561.676056338028,71],["SKPS","Chachag\u00fc\u00ed","Nari\u00f1o Department","medium_airport",3317573.0,46726.380281690144,37047.0,521.7887323943662,71],["SKAR","Armenia","Quindio Department","medium_airport",3067224.0,43200.33802816901,32737.0,461.0845070422535,71],["SKRH","Riohacha","La Guajira Department","medium_airport",2375240.0,33454.08450704225,20663.0,291.0281690140845,71],["SKVP","Valledupar","C\u00e9sar Department","medium_airport",2164016.0,30479.098591549297,23482.0,330.7323943661972,71],["SKUI","Quibd\u00f3","Choc\u00f3 Department","medium_airport",1826104.0,25719.774647887323,52634.0,741.3239436619718,71],["SKNV","Neiva","Huila Department","medium_airport",1666177.0,23467.281690140844,60395.0,850.6338028169014,71],["SKLT","Leticia","Amazonas Department","medium_airport",1662871.0,23420.718309859156,25128.0,353.9154929577465,71],["SKYP","Yopal","Casanare Department","medium_airport",1501989.0,21154.774647887323,68194.0,960.4788732394367,71],["SKVV","Villavicencio","Meta Department","medium_airport",1338882.0,18857.49295774648,32389.0,456.1830985915493,71],["SKLC","Carepa","Antioqu\u00eda Department","medium_airport",1133326.0,15962.338028169013,38499.0,542.2394366197183,71],["SKIB","Ibagu\u00e9","Tolima Department","medium_airport",862852.0,12152.845070422536,39617.0,557.9859154929577,71],["SKUC","Arauca","Arauca Department","medium_airport",807483.0,11373.0,41211.0,580.4366197183099,71],["SKCO","Tumaco","Nari\u00f1o Department","medium_airport",744364.0,10484.0,38262.0,538.9014084507043,71],["SKPP","Popay\u00e1n","Cauca Department","medium_airport",684619.0,9642.521126760563,31045.0,437.2535211267606,71],["SKEJ","Barrancabermeja","Santander Department","medium_airport",622877.0,8772.915492957747,48934.0,689.2112676056338,71],["SKAS","Puerto As\u00eds","Putumayo Department","medium_airport",617128.0,8691.94366197183,18893.0,266.09859154929575,71],["SKFL","Florencia","Caquet\u00e1 Dep ...

# %% [markdown]
# ### 7.8. Mapa 4: clase target predominante por aeropuerto

# %%
from pyspark.sql import Window
df_target_airport = (
    df_geo_base
    .groupBy(
        "icao_code",
        "target_nivel_operacion_mes_siguiente",
    )
    .agg(
        F.count("*").alias("n_meses_clase")
    )
)

window_target_airport = Window.partitionBy("icao_code").orderBy(
    F.desc("n_meses_clase")
)

df_target_airport_top = (
    df_target_airport
    .withColumn(
        "rank_clase",
        F.row_number().over(window_target_airport),
    )
    .filter(F.col("rank_clase") == 1)
    .drop("rank_clase")
)

df_airport_target_geo = (
    df_airport_geo_agg
    .join(
        df_target_airport_top,
        on="icao_code",
        how="left",
    )
)

airport_target_geo_pd = df_airport_target_geo.toPandas()

airport_target_geo_pd["operaciones_total_acum_plot"] = np.log1p(
    airport_target_geo_pd["operaciones_total_acum"]
)

fig_target = mostrar_mapa_plotly(
    df_pd=airport_target_geo_pd,
    lat_col="latitude_deg_num",
    lon_col="longitude_deg_num",
    title="Nivel de operación predominante por aeropuerto",
    color_col="target_nivel_operacion_mes_siguiente",
    size_col="operaciones_total_acum_plot",
    hover_name_col="name",
    hover_data=[
        "icao_code",
        "municipality",
        "region_name",
        "type",
        "target_nivel_operacion_mes_siguiente",
        "n_meses_clase",
        "operaciones_total_acum",
        "pasajeros_total_acum",
    ],
    zoom=4.6,
    height=750,
    map_style="carto-positron",
    size_max=12,
    opacity=0.95,
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="1322f78f-042f-43e6-a687-aea869751152" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1322f78f-042f-43e6-a687-aea869751152")) {                    Plotly.newPlot(                        "1322f78f-042f-43e6-a687-aea869751152",                        [{"customdata":[["SKBO","Bogota","Bogot\u00e1 Capital District","large_airport","alto",66,1744239.0,165476430.0],["SKRG","Medell\u00edn","Antioqu\u00eda Department","large_airport","alto",56,493651.0,57960717.0],["SKMD","Medell\u00edn","Antioqu\u00eda Department","medium_airport","alto",66,181879.0,6606734.0],["SKBG","Bucaramanga","Santander Department","medium_airport","alto",68,141342.0,9737843.0],["SKQU","Mariquita","Tolima Department","medium_airport","alto",46,134185.0,611.0],["SKSM","Santa Marta","Magdalena Department","medium_airport","alto",64,121907.0,16818305.0],["SKPE","Pereira","Risaralda Department","medium_airport","alto",65,108262.0,11681624.0],["SKCC","C\u00facuta","Norte de Santander Department","medium_airport","alto",66,91632.0,7292205.0],["SKMR","Monter\u00eda","C\u00f3rdoba Department","medium_airport","alto",64,71406.0,6900839.0],["SKYP","Yopal","Casanare Department","medium_airport","alto",68,68194.0,1501989.0],["SKNV","Neiva","Huila Department","medium_airport","alto",63,60395.0,1666177.0],["SKGY","Ch\u00eda","Bogot\u00e1 Capital District","small_airport","alto",44,52671.0,12589.0],["SKUI","Quibd\u00f3","Choc\u00f3 Department","medium_airport","alto",65,52634.0,1826104.0],["SKEJ","Barrancabermeja","Santander Department","medium_airport","alto",45,48934.0,622877.0],["SKUC","Arauca","Arauca Department","medium_airport","alto",50,41211.0,807483.0],["SKIB","Ibagu\u00e9","Tolima Department","medium_airport","alto",33,39617.0,862852.0]],"hovertemplate":"<b>%{hovertext}</b><br><br>target_nivel_operacion_mes_siguiente=%{customdata[4]}<br>operaciones_total_acum_plot=%{marker.size}<br>latitude_deg_num=%{lat}<br>longitude_deg_num=%{lon}<br>icao_code=%{customdata[0]}<br>municipality=%{customdata[1]}<br>region_name=%{customdata[2]}<br>type=%{customdata[3]}<br>n_meses_clase=%{customdata[5]}<br>operaciones_total_acum=%{customdata[6]}<br>pasajeros_total_acum=%{customdata[7]}<extra></extra>","hovertext":["El Dorado International Airport","Jose Maria C\u00f3rdova International Airport","Enrique Olaya Herrera Airport","Palonegro Airport","Mariquita Airport","Sim\u00f3n Bol\u00edvar International Airport","Mateca\u00f1a International Airport","Camilo Daza International Airport","Los Garzones Airport","El Alcaravan - Yopal Airport","Benito Salas Airport","Guaymaral Airport","El Cara\u00f1o Airport","Yarigu\u00edes Airport","Santiago Perez Airport","Perales Airport"],"lat":[4.70159,6.16454,6.219686,7.1265,5.21256,11.1196,4.81267,7.92757,8.82374,5.31911,2.95015,4.81233,5.69076,7.02433,7.06888,4.42161],"legendgroup":"alto","lon":[-74.1469,-75.4231,-75.590597,-73.1848,-74.8836,-74.2306,-75.7395,-72.5115,-75.8258,-72.384,-75.294,-74.0649,-76.6412,-73.8068,-70.7369,-75.1333],"marker":{"color":"#636efa","size":[14.37182948866193,13.109586094484847,12.111102407938947,11.858944839433486,11.806982176170209,11.711021940879546,11.592318731032977,11.425546747792179,11.176151182737833,11.130126527360975,11.00867815656436,10.871839284036742,10.871136576685425,10.79824816585992,10.62648475506496,10.587038839422627],"sizemode":"area","sizeref":0.09980437144904118,"opacity":0.95},"mode":"markers","name":"alto","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"customdata":[["SKCL","Cali","Valle del Cauca Department","large_airport","medio",43,306941.0,32231271.0],["SKCG","Cartagena","Bol\u00edvar Department","large_airport","medio",59,253661.0,32688287.0],["SKLC","Carepa","Antioqu\u00eda Depar ...

# %% [markdown]
# ### 7.9. Mapa 5: cobertura METAR promedio por aeropuerto

# %%
airport_metar_geo_pd = (
    df_airport_geo_agg
    .filter(F.col("cobertura_metar_prom").isNotNull())
    .toPandas()
)

airport_metar_geo_pd["n_metar_total_plot"] = np.log1p(
    airport_metar_geo_pd["n_metar_total"]
)

fig_metar = mostrar_mapa_plotly(
    df_pd=airport_metar_geo_pd,
    lat_col="latitude_deg_num",
    lon_col="longitude_deg_num",
    title="Cobertura METAR promedio por aeropuerto",
    color_col="cobertura_metar_prom",
    size_col="n_metar_total_plot",
    hover_name_col="name",
    hover_data=[
        "icao_code",
        "municipality",
        "region_name",
        "type",
        "cobertura_metar_prom",
        "n_metar_total",
        "operaciones_total_acum",
        "pasajeros_total_acum",
    ],
    zoom=4.6,
    height=750,
    map_style="carto-positron",
    size_max=12,
    opacity=0.95,
    color_continuous_scale="Turbo",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="f7d2643e-9980-42f9-a517-2095f91df730" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7d2643e-9980-42f9-a517-2095f91df730")) {                    Plotly.newPlot(                        "f7d2643e-9980-42f9-a517-2095f91df730",                        [{"customdata":[["SKBO","Bogota","Bogot\u00e1 Capital District","large_airport",1.0881674470876672,56437,1744239.0,165476430.0],["SKCL","Cali","Valle del Cauca Department","large_airport",1.0587503702228196,54908,306941.0,32231271.0],["SKRG","Medell\u00edn","Antioqu\u00eda Department","large_airport",1.0456834474900323,54231,493651.0,57960717.0],["SKBQ","Barranquilla","Atl\u00e1ntico Department","large_airport",1.0343663560276504,53646,165595.0,15059954.0],["SKSP","San Andr\u00e9s","San Andr\u00e9s, Providencia y Santa Catalina Department","large_airport",1.0022762952700757,51984,103780.0,12719085.0],["SKLT","Leticia","Amazonas Department","medium_airport",0.9948510849424813,51585,25128.0,1662871.0],["SKCG","Cartagena","Bol\u00edvar Department","large_airport",0.9774874481719142,50685,253661.0,32688287.0],["SKPE","Pereira","Risaralda Department","medium_airport",0.8462473472027318,43879,108262.0,11681624.0],["SKCC","C\u00facuta","Norte de Santander Department","medium_airport",0.820446820398351,42548,91632.0,7292205.0],["SKBG","Bucaramanga","Santander Department","medium_airport",0.7977210003314907,41372,141342.0,9737843.0],["SKSM","Santa Marta","Magdalena Department","medium_airport",0.6886818951653312,35700,121907.0,16818305.0],["SKMR","Monter\u00eda","C\u00f3rdoba Department","medium_airport",0.730414972674701,32538,71406.0,6900839.0],["SKAR","Armenia","Quindio Department","medium_airport",0.6242795358232699,32364,32737.0,3067224.0],["SKVP","Valledupar","C\u00e9sar Department","medium_airport",0.7041241662260072,30334,23482.0,2164016.0],["SKNV","Neiva","Huila Department","medium_airport",0.6857412593946239,30058,60395.0,1666177.0],["SKUC","Arauca","Arauca Department","medium_airport",0.6501462180060092,29912,41211.0,807483.0],["SKIB","Ibagu\u00e9","Tolima Department","medium_airport",0.6546720746449612,28677,39617.0,862852.0],["SKLC","Carepa","Antioqu\u00eda Department","medium_airport",0.6156681440292935,27874,38499.0,1133326.0],["SKVV","Villavicencio","Meta Department","medium_airport",0.5956235579499779,26975,32389.0,1338882.0],["SKUI","Quibd\u00f3","Choc\u00f3 Department","medium_airport",0.5876360745597172,26617,52634.0,1826104.0],["SKPV","Providencia","San Andr\u00e9s, Providencia y Santa Catalina Department","medium_airport",0.5483855585357253,26426,13944.0,352891.0],["SKPC","Puerto Carre\u00f1o","Vichada Department","medium_airport",0.6020521754771616,26379,11136.0,326161.0],["SKRH","Riohacha","La Guajira Department","medium_airport",0.6195253437956058,26235,20663.0,2375240.0],["SKPS","Chachag\u00fc\u00ed","Nari\u00f1o Department","medium_airport",0.5495535610830817,25679,37047.0,3317573.0],["SKEJ","Barrancabermeja","Santander Department","medium_airport",0.5843542409702727,25599,48934.0,622877.0],["SKIP","Ipiales","Nari\u00f1o Department","medium_airport",0.576420903811407,25255,6742.0,444506.0],["SKMD","Medell\u00edn","Antioqu\u00eda Department","medium_airport",0.4756854739552908,23974,181879.0,6606734.0],["SKMZ","Manizales","Caldas Department","medium_airport",0.4682070558262855,20523,15568.0,571346.0],["SKMU","Mit\u00fa","Vaup\u00e9s Department","medium_airport",0.41898430465067,11020,8202.0,279597.0],["SKPP","Popay\u00e1n","Cauca Department","medium_airport",0.3141883435459971,9399,31045.0,684619.0],["SKGY","Ch\u00eda","Bogot\u00e1 Capital District","small_airport",0.3625064256329154,9259,52671.0,12589.0],["SKCZ","Corozal","Sucre Department","medium_airport",0.3831950858230 ...

# %% [markdown]
# ### 7.10. Mapa 6: temperatura media promedio por aeropuerto

# %%
airport_temp_geo_pd = (
    df_airport_geo_agg
    .filter(F.col("temp_media_prom_c").isNotNull())
    .toPandas()
)

airport_temp_geo_pd["operaciones_total_acum_plot"] = np.log1p(
    airport_temp_geo_pd["operaciones_total_acum"]
)

fig_temp = mostrar_mapa_plotly(
    df_pd=airport_temp_geo_pd,
    lat_col="latitude_deg_num",
    lon_col="longitude_deg_num",
    title="Temperatura media promedio por aeropuerto",
    color_col="temp_media_prom_c",
    size_col="operaciones_total_acum_plot",
    hover_name_col="name",
    hover_data=[
        "icao_code",
        "municipality",
        "region_name",
        "type",
        "temp_media_prom_c",
        "operaciones_total_acum",
        "pasajeros_total_acum",
    ],
    zoom=4.6,
    height=750,
    map_style="carto-positron",
    size_max=12,
    opacity=0.95,
    color_continuous_scale="Turbo",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="676e92b5-2dfe-407a-a43e-96ad406c86b2" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("676e92b5-2dfe-407a-a43e-96ad406c86b2")) {                    Plotly.newPlot(                        "676e92b5-2dfe-407a-a43e-96ad406c86b2",                        [{"customdata":[["SKBO","Bogota","Bogot\u00e1 Capital District","large_airport",14.077529023199535,1744239.0,165476430.0],["SKRG","Medell\u00edn","Antioqu\u00eda Department","large_airport",16.85756731805553,493651.0,57960717.0],["SKCL","Cali","Valle del Cauca Department","large_airport",23.668026624603584,306941.0,32231271.0],["SKCG","Cartagena","Bol\u00edvar Department","large_airport",28.44026973196675,253661.0,32688287.0],["SKMD","Medell\u00edn","Antioqu\u00eda Department","medium_airport",23.464979773967485,181879.0,6606734.0],["SKBQ","Barranquilla","Atl\u00e1ntico Department","large_airport",27.909855418319417,165595.0,15059954.0],["SKBG","Bucaramanga","Santander Department","medium_airport",22.537703016476225,141342.0,9737843.0],["SKQU","Mariquita","Tolima Department","medium_airport",27.010147698682395,134185.0,611.0],["SKSM","Santa Marta","Magdalena Department","medium_airport",29.391287587027044,121907.0,16818305.0],["SKPE","Pereira","Risaralda Department","medium_airport",22.248524333744143,108262.0,11681624.0],["SKSP","San Andr\u00e9s","San Andr\u00e9s, Providencia y Santa Catalina Department","large_airport",28.30174845703769,103780.0,12719085.0],["SKCC","C\u00facuta","Norte de Santander Department","medium_airport",27.860574302544997,91632.0,7292205.0],["SKMR","Monter\u00eda","C\u00f3rdoba Department","medium_airport",28.656311768689747,71406.0,6900839.0],["SKYP","Yopal","Casanare Department","medium_airport",27.214150724431068,68194.0,1501989.0],["SKNV","Neiva","Huila Department","medium_airport",28.401407889747592,60395.0,1666177.0],["SKGY","Ch\u00eda","Bogot\u00e1 Capital District","small_airport",15.100749100612955,52671.0,12589.0],["SKUI","Quibd\u00f3","Choc\u00f3 Department","medium_airport",26.987365212276387,52634.0,1826104.0],["SKEJ","Barrancabermeja","Santander Department","medium_airport",28.90068418153175,48934.0,622877.0],["SKUC","Arauca","Arauca Department","medium_airport",28.036424431350923,41211.0,807483.0],["SKIB","Ibagu\u00e9","Tolima Department","medium_airport",25.081476311335862,39617.0,862852.0],["SKLC","Carepa","Antioqu\u00eda Department","medium_airport",28.06161080191747,38499.0,1133326.0],["SKCO","Tumaco","Nari\u00f1o Department","medium_airport",26.6379377061949,38262.0,744364.0],["SKPS","Chachag\u00fc\u00ed","Nari\u00f1o Department","medium_airport",19.8789274818551,37047.0,3317573.0],["SKAR","Armenia","Quindio Department","medium_airport",22.805515468683488,32737.0,3067224.0],["SKVV","Villavicencio","Meta Department","medium_airport",26.459286354821486,32389.0,1338882.0],["SKPP","Popay\u00e1n","Cauca Department","medium_airport",19.46220582659393,31045.0,684619.0],["SKSA","Saravena","Arauca Department","small_airport",26.51698275762135,28087.0,227619.0],["SKSJ","San Jos\u00e9 Del Guaviare","Guaviare Department","medium_airport",27.001843692689796,26177.0,212122.0],["SKLT","Leticia","Amazonas Department","medium_airport",26.069811265968177,25128.0,1662871.0],["SKGI","Girardot","Cundinamarca Department","medium_airport",29.167683206032873,23495.0,5021.0],["SKVP","Valledupar","C\u00e9sar Department","medium_airport",29.913358917758377,23482.0,2164016.0],["SKFL","Florencia","Caquet\u00e1 Department","medium_airport",26.313341944720552,21731.0,575184.0],["SKRH","Riohacha","La Guajira Department","medium_airport",29.73719351873085,20663.0,2375240.0],["SKAS","Puerto As\u00eds","Putumayo Department","medium_airport",25.46456962442969,18893.0,617128.0],["S ...

# %% [markdown]
# ### 7.11. Mapa 7: viento medio promedio por aeropuerto

# %%
airport_wind_geo_pd = (
    df_airport_geo_agg
    .filter(F.col("viento_medio_prom_kt").isNotNull())
    .toPandas()
)

airport_wind_geo_pd["operaciones_total_acum_plot"] = np.log1p(
    airport_wind_geo_pd["operaciones_total_acum"]
)

fig_viento = mostrar_mapa_plotly(
    df_pd=airport_wind_geo_pd,
    lat_col="latitude_deg_num",
    lon_col="longitude_deg_num",
    title="Viento medio promedio por aeropuerto",
    color_col="viento_medio_prom_kt",
    size_col="operaciones_total_acum_plot",
    hover_name_col="name",
    hover_data=[
        "icao_code",
        "municipality",
        "region_name",
        "type",
        "viento_medio_prom_kt",
        "operaciones_total_acum",
        "pasajeros_total_acum",
    ],
    zoom=4.6,
    height=750,
    map_style="carto-positron",
    size_max=12,
    opacity=0.95,
    color_continuous_scale="Turbo",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="cd52fe34-54fd-4a7f-8803-64a7daa6152d" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd52fe34-54fd-4a7f-8803-64a7daa6152d")) {                    Plotly.newPlot(                        "cd52fe34-54fd-4a7f-8803-64a7daa6152d",                        [{"customdata":[["SKBO","Bogota","Bogot\u00e1 Capital District","large_airport",5.075974035603335,1744239.0,165476430.0],["SKRG","Medell\u00edn","Antioqu\u00eda Department","large_airport",4.153458172151958,493651.0,57960717.0],["SKCL","Cali","Valle del Cauca Department","large_airport",4.5787983853328145,306941.0,32231271.0],["SKCG","Cartagena","Bol\u00edvar Department","large_airport",6.156424919421658,253661.0,32688287.0],["SKMD","Medell\u00edn","Antioqu\u00eda Department","medium_airport",5.804461168560966,181879.0,6606734.0],["SKBQ","Barranquilla","Atl\u00e1ntico Department","large_airport",6.628398072670833,165595.0,15059954.0],["SKBG","Bucaramanga","Santander Department","medium_airport",4.391734867058646,141342.0,9737843.0],["SKQU","Mariquita","Tolima Department","medium_airport",3.891460806038103,134185.0,611.0],["SKSM","Santa Marta","Magdalena Department","medium_airport",6.412679419740538,121907.0,16818305.0],["SKPE","Pereira","Risaralda Department","medium_airport",4.503743260977702,108262.0,11681624.0],["SKSP","San Andr\u00e9s","San Andr\u00e9s, Providencia y Santa Catalina Department","large_airport",8.623831180103732,103780.0,12719085.0],["SKCC","C\u00facuta","Norte de Santander Department","medium_airport",7.424352992896726,91632.0,7292205.0],["SKMR","Monter\u00eda","C\u00f3rdoba Department","medium_airport",3.5810464015612795,71406.0,6900839.0],["SKYP","Yopal","Casanare Department","medium_airport",5.755265098225171,68194.0,1501989.0],["SKNV","Neiva","Huila Department","medium_airport",4.464484440220522,60395.0,1666177.0],["SKGY","Ch\u00eda","Bogot\u00e1 Capital District","small_airport",4.971917084653782,52671.0,12589.0],["SKUI","Quibd\u00f3","Choc\u00f3 Department","medium_airport",3.3594391746165795,52634.0,1826104.0],["SKEJ","Barrancabermeja","Santander Department","medium_airport",3.299393455087492,48934.0,622877.0],["SKUC","Arauca","Arauca Department","medium_airport",2.69857446615161,41211.0,807483.0],["SKIB","Ibagu\u00e9","Tolima Department","medium_airport",4.6638734436409655,39617.0,862852.0],["SKLC","Carepa","Antioqu\u00eda Department","medium_airport",5.1671271091894315,38499.0,1133326.0],["SKCO","Tumaco","Nari\u00f1o Department","medium_airport",4.969279709550921,38262.0,744364.0],["SKPS","Chachag\u00fc\u00ed","Nari\u00f1o Department","medium_airport",4.509400168307792,37047.0,3317573.0],["SKAR","Armenia","Quindio Department","medium_airport",1.980678798572278,32737.0,3067224.0],["SKVV","Villavicencio","Meta Department","medium_airport",3.4503609453183213,32389.0,1338882.0],["SKPP","Popay\u00e1n","Cauca Department","medium_airport",3.234128725868066,31045.0,684619.0],["SKSA","Saravena","Arauca Department","small_airport",3.4546990911025905,28087.0,227619.0],["SKSJ","San Jos\u00e9 Del Guaviare","Guaviare Department","medium_airport",2.643782607407478,26177.0,212122.0],["SKLT","Leticia","Amazonas Department","medium_airport",2.3814742980228982,25128.0,1662871.0],["SKGI","Girardot","Cundinamarca Department","medium_airport",3.8682225868976476,23495.0,5021.0],["SKVP","Valledupar","C\u00e9sar Department","medium_airport",8.279745628642042,23482.0,2164016.0],["SKFL","Florencia","Caquet\u00e1 Department","medium_airport",2.5267005018922384,21731.0,575184.0],["SKRH","Riohacha","La Guajira Department","medium_airport",9.540535845071519,20663.0,2375240.0],["SKAS","Puerto As\u00eds","Putumayo Department","medium_airport",2.650052627714247,18893.0,617128.0],["SKTM","Tame", ...

# %% [markdown]
# ### 7.12. Mapa 8: visibilidad media promedio por aeropuerto

# %%
airport_vis_geo_pd = (
    df_airport_geo_agg
    .filter(F.col("visibilidad_media_prom_sm").isNotNull())
    .toPandas()
)

airport_vis_geo_pd["operaciones_total_acum_plot"] = np.log1p(
    airport_vis_geo_pd["operaciones_total_acum"]
)

fig_visibilidad = mostrar_mapa_plotly(
    df_pd=airport_vis_geo_pd,
    lat_col="latitude_deg_num",
    lon_col="longitude_deg_num",
    title="Visibilidad media promedio por aeropuerto",
    color_col="visibilidad_media_prom_sm",
    size_col="operaciones_total_acum_plot",
    hover_name_col="name",
    hover_data=[
        "icao_code",
        "municipality",
        "region_name",
        "type",
        "visibilidad_media_prom_sm",
        "operaciones_total_acum",
        "pasajeros_total_acum",
    ],
    zoom=4.6,
    height=750,
    map_style="carto-positron",
    size_max=12,
    opacity=0.95,
    color_continuous_scale="Turbo",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="f073e9af-cc29-4938-b849-21d22279cce9" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f073e9af-cc29-4938-b849-21d22279cce9")) {                    Plotly.newPlot(                        "f073e9af-cc29-4938-b849-21d22279cce9",                        [{"customdata":[["SKBO","Bogota","Bogot\u00e1 Capital District","large_airport",5.934724246158952,1744239.0,165476430.0],["SKRG","Medell\u00edn","Antioqu\u00eda Department","large_airport",5.415566360999653,493651.0,57960717.0],["SKCL","Cali","Valle del Cauca Department","large_airport",5.7374991412208605,306941.0,32231271.0],["SKCG","Cartagena","Bol\u00edvar Department","large_airport",6.128789864068513,253661.0,32688287.0],["SKMD","Medell\u00edn","Antioqu\u00eda Department","medium_airport",6.033082996434448,181879.0,6606734.0],["SKBQ","Barranquilla","Atl\u00e1ntico Department","large_airport",5.906370372730164,165595.0,15059954.0],["SKBG","Bucaramanga","Santander Department","medium_airport",5.810880224163558,141342.0,9737843.0],["SKQU","Mariquita","Tolima Department","medium_airport",5.599536672648374,134185.0,611.0],["SKSM","Santa Marta","Magdalena Department","medium_airport",6.174242611793648,121907.0,16818305.0],["SKPE","Pereira","Risaralda Department","medium_airport",5.759533697413472,108262.0,11681624.0],["SKSP","San Andr\u00e9s","San Andr\u00e9s, Providencia y Santa Catalina Department","large_airport",6.082661714345498,103780.0,12719085.0],["SKCC","C\u00facuta","Norte de Santander Department","medium_airport",5.7916119790196605,91632.0,7292205.0],["SKMR","Monter\u00eda","C\u00f3rdoba Department","medium_airport",5.964063013028043,71406.0,6900839.0],["SKYP","Yopal","Casanare Department","medium_airport",5.643187321227427,68194.0,1501989.0],["SKNV","Neiva","Huila Department","medium_airport",6.006646340305851,60395.0,1666177.0],["SKGY","Ch\u00eda","Bogot\u00e1 Capital District","small_airport",5.321334872925168,52671.0,12589.0],["SKUI","Quibd\u00f3","Choc\u00f3 Department","medium_airport",5.064918733185856,52634.0,1826104.0],["SKEJ","Barrancabermeja","Santander Department","medium_airport",6.0950010500211675,48934.0,622877.0],["SKUC","Arauca","Arauca Department","medium_airport",6.072387085077572,41211.0,807483.0],["SKIB","Ibagu\u00e9","Tolima Department","medium_airport",5.954246028395079,39617.0,862852.0],["SKLC","Carepa","Antioqu\u00eda Department","medium_airport",5.993609593951159,38499.0,1133326.0],["SKCO","Tumaco","Nari\u00f1o Department","medium_airport",5.730218741373178,38262.0,744364.0],["SKPS","Chachag\u00fc\u00ed","Nari\u00f1o Department","medium_airport",5.653476491875817,37047.0,3317573.0],["SKAR","Armenia","Quindio Department","medium_airport",5.593383292659442,32737.0,3067224.0],["SKVV","Villavicencio","Meta Department","medium_airport",5.854386622014706,32389.0,1338882.0],["SKPP","Popay\u00e1n","Cauca Department","medium_airport",5.462652304445194,31045.0,684619.0],["SKSA","Saravena","Arauca Department","small_airport",5.763344416327889,28087.0,227619.0],["SKSJ","San Jos\u00e9 Del Guaviare","Guaviare Department","medium_airport",5.894126911564768,26177.0,212122.0],["SKLT","Leticia","Amazonas Department","medium_airport",5.942967531616289,25128.0,1662871.0],["SKGI","Girardot","Cundinamarca Department","medium_airport",5.654366742516048,23495.0,5021.0],["SKVP","Valledupar","C\u00e9sar Department","medium_airport",6.109836126438742,23482.0,2164016.0],["SKFL","Florencia","Caquet\u00e1 Department","medium_airport",5.720630305917303,21731.0,575184.0],["SKRH","Riohacha","La Guajira Department","medium_airport",6.188353302285226,20663.0,2375240.0],["SKAS","Puerto As\u00eds","Putumayo Department","medium_airport",5.5944757317978615,18893.0,617128.0],["SKTM","Tame","Arau ...

# %% [markdown]
# ### 7.13. Resumen regional de operaciones

# %%
df_region_geo_summary = (
    df_geo_base
    .groupBy("region_name")
    .agg(
        F.countDistinct("icao_code").alias("n_aeropuertos"),
        F.sum("operaciones_total").alias("operaciones_total_acum"),
        F.avg("operaciones_total").alias("operaciones_prom_mes"),
        F.sum("pasajeros_total").alias("pasajeros_total_acum"),
        F.avg("pasajeros_total").alias("pasajeros_prom_mes"),
        F.avg("cobertura_metar_ratio").alias("cobertura_metar_prom"),
    )
    .orderBy(F.desc("operaciones_total_acum"))
)

display(df_region_geo_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region_name</th><th>n_aeropuertos</th><th>operaciones_total_acum</th><th>operaciones_prom_mes</th><th>pasajeros_total_acum</th><th>pasajeros_prom_mes</th><th>cobertura_metar_prom</th></tr></thead><tbody><tr><td>Bogotá Capital District</td><td>2</td><td>1796910.0</td><td>12654.295774647888</td><td>1.65489019E8</td><td>1165415.6267605633</td><td>0.8485623928337398</td></tr><tr><td>Antioquía Department</td><td>3</td><td>714029.0</td><td>3352.2488262910797</td><td>6.5700777E7</td><td>308454.3521126761</td><td>0.7189962742798195</td></tr><tr><td>Valle del Cauca Department</td><td>3</td><td>312306.0</td><td>1508.7246376811595</td><td>3.2277548E7</td><td>155930.18357487922</td><td>0.6681323360360086</td></tr><tr><td>Bolívar Department</td><td>1</td><td>253661.0</td><td>3572.6901408450703</td><td>3.2688287E7</td><td>460398.40845070424</td><td>0.9774874481719142</td></tr><tr><td>Santander Department</td><td>2</td><td>190276.0</td><td>1339.9718309859154</td><td>1.036072E7</td><td>72962.81690140846</td><td>0.6999957670362764</td></tr><tr><td>Tolima Department</td><td>2</td><td>173802.0</td><td>1223.9577464788733</td><td>863463.0</td><td>6080.725352112676</td><td>0.5336696448059103</td></tr><tr><td>Atlántico Department</td><td>1</td><td>165595.0</td><td>2332.323943661972</td><td>1.5059954E7</td><td>212112.02816901408</td><td>1.0343663560276504</td></tr><tr><td>Magdalena Department</td><td>1</td><td>121907.0</td><td>1717.0</td><td>1.6818305E7</td><td>236877.53521126762</td><td>0.6886818951653312</td></tr><tr><td>San Andrés, Providencia y Santa Catalina Department</td><td>2</td><td>117724.0</td><td>829.0422535211268</td><td>1.3071976E7</td><td>92056.1690140845</td><td>0.7836136045805345</td></tr><tr><td>Risaralda Department</td><td>1</td><td>108262.0</td><td>1524.8169014084508</td><td>1.1681624E7</td><td>164529.91549295775</td><td>0.8462473472027318</td></tr><tr><td>Norte de Santander Department</td><td>1</td><td>91632.0</td><td>1290.5915492957747</td><td>7292205.0</td><td>102707.11267605633</td><td>0.820446820398351</td></tr><tr><td>Arauca Department</td><td>3</td><td>85443.0</td><td>401.14084507042253</td><td>1082758.0</td><td>5083.370892018779</td><td>0.5279066723166834</td></tr><tr><td>Nariño Department</td><td>3</td><td>82051.0</td><td>385.21596244131456</td><td>4506443.0</td><td>21157.009389671362</td><td>0.5109453927304506</td></tr><tr><td>Córdoba Department</td><td>1</td><td>71406.0</td><td>1005.7183098591549</td><td>6900839.0</td><td>97194.91549295775</td><td>0.730414972674701</td></tr><tr><td>Casanare Department</td><td>1</td><td>68194.0</td><td>960.4788732394367</td><td>1501989.0</td><td>21154.774647887323</td><td>0.294249769916309</td></tr><tr><td>Chocó Department</td><td>2</td><td>61722.0</td><td>434.6619718309859</td><td>2292100.0</td><td>16141.549295774648</td><td>0.49386936200453874</td></tr><tr><td>Huila Department</td><td>1</td><td>60395.0</td><td>850.6338028169014</td><td>1666177.0</td><td>23467.281690140844</td><td>0.6857412593946239</td></tr><tr><td>Cauca Department</td><td>2</td><td>43192.0</td><td>304.16901408450707</td><td>1041661.0</td><td>7335.640845070423</td><td>0.27273086092607784</td></tr><tr><td>Quindio Department</td><td>1</td><td>32737.0</td><td>461.0845070422535</td><td>3067224.0</td><td>43200.33802816901</td><td>0.6242795358232699</td></tr><tr><td>Meta Department</td><td>1</td><td>32389.0</td><td>456.1830985915493</td><td>1338882.0</td><td>18857.49295774648</td><td>0.5956235579499779</td></tr><tr><td>Guaviare Department</td><td>1</td><td>26177.0</td><td>368.6901408450704</td><td>212122.0</td><td>2987.6338028169016</td><td>0.36717598845866367</td></tr><tr><td>Amazonas Department</td><td>1</td><td>25128.0</td><td>353.9154929577465</td><td>1662871.0</td><td>23420.718309859156</td><td>0.9948510849424813</td></tr><tr><td>Cundinamarca Department</td><td>1</td><td>23495.0</td><td>361.461538461538 ...

# %% [markdown]
# ### 7.14. Gráfico regional de operaciones

# %%
region_geo_pd = df_region_geo_summary.toPandas()

fig_region = px.bar(
    region_geo_pd.sort_values("operaciones_total_acum"),
    x="operaciones_total_acum",
    y="region_name",
    orientation="h",
    title="Operaciones acumuladas por región",
    hover_data={
        "n_aeropuertos": True,
        "operaciones_total_acum": ":,.0f",
        "operaciones_prom_mes": ":,.1f",
        "pasajeros_total_acum": ":,.0f",
        "pasajeros_prom_mes": ":,.1f",
        "cobertura_metar_prom": ":.2f",
    },
)

fig_region.update_layout(
    height=750,
    template="plotly_white",
    margin={
        "r": 20,
        "t": 60,
        "l": 20,
        "b": 40,
    },
    title={
        "x": 0.5,
        "xanchor": "center",
    },
    xaxis_title="Operaciones acumuladas",
    yaxis_title="Región",
)

fig_region.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.12.1.min.js"></script>                <div id="45549f0f-8a06-4bac-bdd5-a04bf75b3422" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45549f0f-8a06-4bac-bdd5-a04bf75b3422")) {                    Plotly.newPlot(                        "45549f0f-8a06-4bac-bdd5-a04bf75b3422",                        [{"alignmentgroup":"True","customdata":[[1.0,115.52112676056338,279597.0,3937.9859154929577,0.41898430465067],[1.0,123.92957746478874,251722.0,3545.3802816901407,0.38319508582300577],[1.0,156.8450704225352,326161.0,4593.816901408451,0.6020521754771616],[1.0,175.92957746478874,0.0,0.0,0.31818031338331665],[1.0,219.26760563380282,571346.0,8047.12676056338,0.4682070558262855],[1.0,266.09859154929575,617128.0,8691.94366197183,0.338912854166509],[1.0,291.0281690140845,2375240.0,33454.08450704225,0.6195253437956058],[1.0,306.07042253521126,575184.0,8101.183098591549,0.4049852091683293],[1.0,330.7323943661972,2164016.0,30479.098591549297,0.7041241662260072],[1.0,361.46153846153845,5021.0,77.24615384615385,0.16812406710209826],[1.0,353.9154929577465,1662871.0,23420.718309859156,0.9948510849424813],[1.0,368.6901408450704,212122.0,2987.6338028169016,0.36717598845866367],[1.0,456.1830985915493,1338882.0,18857.49295774648,0.5956235579499779],[1.0,461.0845070422535,3067224.0,43200.33802816901,0.6242795358232699],[2.0,304.16901408450707,1041661.0,7335.640845070423,0.27273086092607784],[1.0,850.6338028169014,1666177.0,23467.281690140844,0.6857412593946239],[2.0,434.6619718309859,2292100.0,16141.549295774648,0.49386936200453874],[1.0,960.4788732394367,1501989.0,21154.774647887323,0.294249769916309],[1.0,1005.7183098591549,6900839.0,97194.91549295775,0.730414972674701],[3.0,385.21596244131456,4506443.0,21157.009389671362,0.5109453927304506],[3.0,401.14084507042253,1082758.0,5083.370892018779,0.5279066723166834],[1.0,1290.5915492957747,7292205.0,102707.11267605633,0.820446820398351],[1.0,1524.8169014084508,11681624.0,164529.91549295775,0.8462473472027318],[2.0,829.0422535211268,13071976.0,92056.1690140845,0.7836136045805345],[1.0,1717.0,16818305.0,236877.53521126762,0.6886818951653312],[1.0,2332.323943661972,15059954.0,212112.02816901408,1.0343663560276504],[2.0,1223.9577464788733,863463.0,6080.725352112676,0.5336696448059103],[2.0,1339.9718309859154,10360720.0,72962.81690140846,0.6999957670362764],[1.0,3572.6901408450703,32688287.0,460398.40845070424,0.9774874481719142],[3.0,1508.7246376811595,32277548.0,155930.18357487922,0.6681323360360086],[3.0,3352.2488262910797,65700777.0,308454.3521126761,0.7189962742798195],[2.0,12654.295774647888,165489019.0,1165415.6267605633,0.8485623928337398]],"hovertemplate":"operaciones_total_acum=%{x:,.0f}<br>region_name=%{y}<br>n_aeropuertos=%{customdata[0]}<br>operaciones_prom_mes=%{customdata[1]:,.1f}<br>pasajeros_total_acum=%{customdata[2]:,.0f}<br>pasajeros_prom_mes=%{customdata[3]:,.1f}<br>cobertura_metar_prom=%{customdata[4]:.2f}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[8202.0,8799.0,11136.0,12491.0,15568.0,18893.0,20663.0,21731.0,23482.0,23495.0,25128.0,26177.0,32389.0,32737.0,43192.0,60395.0,61722.0,68194.0,71406.0,82051.0,85443.0,91632.0,108262.0,117724.0,121907.0,165595.0,173802.0,190276.0,253661.0,312306.0,714029.0,1796910.0],"xaxis":"x","y":["Vaup\u00e9s Department","Sucre Department","Vichada Department","Guain\u00eda Department","Caldas Department","Putumayo Department","La Guajira Department","Caquet\u00e1 Department","C\u00e9sar Department","Cundinamarca Department","Amazonas Department","Guaviare Department","Meta Department","Quindio Department","Cauca Department","Huila Department","Choc\u00f3 Department","Casanare Departme ...

# %% [markdown]
# ### 7.15. Guardar mapas como HTML interactivo

# %%
GEO_EDA_DIR = GOLD_MONTHLY_DIR / "eda_geo"

GEO_EDA_DIR.mkdir(
    parents=True,
    exist_ok=True,
)

fig_geo.write_html(
    str(GEO_EDA_DIR / "mapa_01_aeropuertos_tipo.html")
)

fig_operaciones.write_html(
    str(GEO_EDA_DIR / "mapa_02_operaciones_aeropuerto.html")
)

fig_pasajeros.write_html(
    str(GEO_EDA_DIR / "mapa_03_pasajeros_aeropuerto.html")
)

fig_target.write_html(
    str(GEO_EDA_DIR / "mapa_04_target_predominante.html")
)

fig_metar.write_html(
    str(GEO_EDA_DIR / "mapa_05_cobertura_metar.html")
)

fig_temp.write_html(
    str(GEO_EDA_DIR / "mapa_06_temperatura_media.html")
)

fig_viento.write_html(
    str(GEO_EDA_DIR / "mapa_07_viento_medio.html")
)

fig_visibilidad.write_html(
    str(GEO_EDA_DIR / "mapa_08_visibilidad_media.html")
)

fig_region.write_html(
    str(GEO_EDA_DIR / "grafico_09_operaciones_region.html")
)

print("[OK] Mapas y gráficos geográficos guardados en:")
print(GEO_EDA_DIR)
# Out:
# [OK] Mapas y gráficos geográficos guardados en:
# /Volumes/workspace/default/proyecto_aeropuertos/gold/monthly_airport_dataset/eda_geo

# %% [markdown]
# ## 8. Correlaciones con el target

# %%
target_col = "target_operaciones_total_mes_siguiente"

columnas_excluir = [
    "target_q33_operaciones",
    "target_q66_operaciones",
    "target_nivel_operacion_mes_siguiente",
]

cols_numericas = (
    df
    .select_dtypes(include="number")
    .columns
    .drop(columnas_excluir, errors="ignore")
    .to_list()
)

if target_col not in cols_numericas:
    raise ValueError(f"No existe la columna target numérica: {target_col}")

corr_con_target = (
    df[cols_numericas]
    .corr(method="spearman")[target_col]
    .drop(target_col, errors="ignore")
    .dropna()
    .sort_values()
)

top_n_pos = 15
top_n_neg = 15

corr_negativas = corr_con_target.head(top_n_neg)

corr_positivas = corr_con_target.tail(top_n_pos).sort_values(ascending=False)

cols_corr_negativas = corr_negativas.index.to_list()

cols_corr_positivas = corr_positivas.index.to_list()

cols_clave_corr = (
    cols_corr_positivas
    + [
        col
        for col in cols_corr_negativas
        if col not in cols_corr_positivas
    ]
)

cols_heatmap = cols_clave_corr + [target_col]

top_n = top_n_pos + top_n_neg + 1

# %%
# --- 8.1.1. Correlación Pearson de variables numéricas con el target numérico ---
corr_target = (
    df[cols_heatmap]
    .corr(method='pearson')['target_operaciones_total_mes_siguiente']
    .drop('target_operaciones_total_mes_siguiente')
    .sort_values()
)

fig, ax = plt.subplots(figsize=(9, 9))
colors = ['#D65F5F' if v > 0 else '#4878CF' for v in corr_target.values]
bars   = ax.barh(corr_target.index, corr_target.values, color=colors, edgecolor='white')

# Zonas de referencia
ax.axvspan(-1, -0.3, alpha=0.05, color='blue')
ax.axvspan(0.3,  1,  alpha=0.05, color='red')
ax.axvline(0,    color='black', linewidth=0.8)
ax.axvline(0.7,  color='red',   linestyle=':', linewidth=0.8, label='|r|=0.3')
ax.axvline(-0.7, color='blue',  linestyle=':', linewidth=0.8)

for bar, val in zip(bars, corr_target.values):
    ax.text(val + (0.01 if val >= 0 else -0.01),
            bar.get_y() + bar.get_height()/2,
            f'{val:.3f}', va='center',
            ha='left' if val >= 0 else 'right', fontsize=8)
ax.set_title('Correlación de Pearson con el target numérico\n(azul = negativa, rojo = positiva)',
             fontweight='bold')
ax.set_xlabel('Correlación')
ax.legend(fontsize=9)
ax.set_xlim(-1.05, 1.05)
plt.tight_layout()
plt.show()

# %%
# --- 8.1.2 Heatmap de correlación pearson entre variables clave ---
corr_matrix_pearson = df[cols_heatmap].corr(method="pearson")

figsize_base = max(10, len(cols_heatmap) * 0.65)

fig, ax = plt.subplots(figsize=(figsize_base, figsize_base * 0.85))

mask = np.triu(
    np.ones_like(corr_matrix_pearson, dtype=bool)
)

sns.heatmap(
    corr_matrix_pearson, mask=mask, annot=True, fmt=".2f", cmap="RdBu_r", 
    center=0, vmin=-1, vmax=1, ax=ax, linewidths=0.5, 
    linecolor="white", square=True,
    cbar_kws={
        "shrink": 0.75,
        "label": "Correlación de Pearson",
    },
    annot_kws={
        "size": 8,
    },
)

ax.set_title(
    f"Matriz de correlación de Pearson — Top {top_n} variables asociadas al target",
    fontweight="bold",
    fontsize=14, pad=18,
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45, ha="right", fontsize=9,
)

ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0, fontsize=9,
)

plt.tight_layout()
plt.show()

# %%
# --- 8.2.1 Correlación Spearman de variables explicativas numéricas con el target numérico ---
corr_target = (
    df[cols_heatmap]
    .corr(method='spearman')['target_operaciones_total_mes_siguiente']
    .drop('target_operaciones_total_mes_siguiente')
    .sort_values()
)

fig, ax = plt.subplots(figsize=(9, 9))

colors = [
    "#D65F5F" if v > 0 else "#4878CF"
    for v in corr_target.values
]

bars = ax.barh(
    corr_target.index,
    corr_target.values,
    color=colors,
    edgecolor="white"
)

ax.axvspan(-1, -0.3, alpha=0.05, color="blue")
ax.axvspan(0.3, 1, alpha=0.05, color="red")
ax.axvline(0, color="black", linewidth=0.8)
ax.axvline(0.7, color="red", linestyle=":", linewidth=0.8, label="|r|=0.7")
ax.axvline(-0.7, color="blue", linestyle=":", linewidth=0.8, label="|r|=-0.7")

for bar, val in zip(bars, corr_target.values):
    ax.text(
        val + (0.01 if val >= 0 else -0.01),
        bar.get_y() + bar.get_height() / 2,
        f"{val:.3f}",
        va="center",
        ha="left" if val >= 0 else "right",
        fontsize=8,
    )

ax.set_title(
    "Correlación de Spearman entre variables explicativas y target numérico\n"
    "(azul = negativa, rojo = positiva)",
    fontweight="bold",
)

ax.set_xlabel("Correlación de Spearman")
ax.legend(fontsize=9)
ax.set_xlim(-1.05, 1.05)

plt.tight_layout()
plt.show()

# %%
# --- 8.2.2 Heatmap de correlación spearman entre variables clave ---
corr_matrix_spearman = df[cols_heatmap].corr(method="spearman")

figsize_base = max(10, len(cols_heatmap) * 0.65)

fig, ax = plt.subplots(figsize=(figsize_base, figsize_base * 0.85))

mask = np.triu(
    np.ones_like(corr_matrix_spearman, dtype=bool)
)

sns.heatmap(
    corr_matrix_spearman, mask=mask, annot=True, fmt=".2f", cmap="RdBu_r",
    center=0, vmin=-1, vmax=1, ax=ax,
    linewidths=0.5, linecolor="white", square=True,
    cbar_kws={
        "shrink": 0.75,
        "label": "Correlación de Spearman",
    },
    annot_kws={
        "size": 8,
    },
)

ax.set_title(
    f"Matriz de correlación de Spearman — Top {top_n} variables asociadas al target",
    fontweight="bold",
    fontsize=14, pad=18,
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45, ha="right", fontsize=9,
)

ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0, fontsize=9,
)

plt.tight_layout()
plt.show()

# %%
diff = corr_matrix_spearman - corr_matrix_pearson


figsize_base = max(10, len(cols_heatmap) * 0.65)

fig, ax = plt.subplots(figsize=(figsize_base, figsize_base * 0.85))

mask = np.triu(
    np.ones_like(diff, dtype=bool)
)

sns.heatmap(
    diff, mask=mask, annot=True, fmt=".2f", cmap="RdBu_r",
    center=0, vmin=-1, vmax=1, ax=ax,
    linewidths=0.5, linecolor="white", square=True,
    cbar_kws={
        "shrink": 0.75,
        "label": "Correlación de Spearman",
    },
    annot_kws={
        "size": 8,
    },
)

ax.set_title(
    f"Matriz de diferencia entre correlaciónes — Top {top_n} variables asociadas al target",
    fontweight="bold",
    fontsize=14, pad=18,
)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45, ha="right", fontsize=9,
)

ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0, fontsize=9,
)

plt.tight_layout()
plt.show()
